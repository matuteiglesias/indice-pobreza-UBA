# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import numpy as np

from IPython.core.display import display, HTML
from IPython.display import Markdown as md

from matplotlib.ticker import EngFormatter

import warnings
warnings.filterwarnings('ignore')

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def myround(x, base=5):
    return base * round(x/base)
#     return base * (x/base).round()


# Estilo verde-rojito
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val > 0 else 'black'
    if val < 0: color = 'green'
    return 'color: %s' % color

# Estilo gris
def color_gray(val):
    color = '.5'
    return 'color: %s' % color

# %%
display(HTML("<style>.rendered_html {font-size: 16px; line-height: 1.8; text-indent: 2rem}</style>"))
# display(HTML("<style>.rendered_html {  }</style>"))
# Out:
# <style>.rendered_html {font-size: 16px; line-height: 1.8; text-indent: 2rem}</style>

# %%
frac = 0.02

# %%
yrs_pob_data = 3

# %%
aglo_labels = pd.read_csv('./../data/aglo_labels.csv')[['AGLOMERADO', 'NOMAGLO']]

radio_ref = pd.read_csv('./../data/radio_ref.csv')
# radio_ref[['PROV','NOMPROV','DPTO', 'NOMDPTO']].drop_duplicates().to_csv('./../data/DPTO_PROV.csv', index = False)
dpto_region = pd.read_csv('./../data/DPTO_PROV_Region.csv')
radio_ref = radio_ref.merge(dpto_region)
radio_ref = radio_ref[['RADIO_REF_ID', 'NOMDPTO','NOMPROV', 'AGLOMERADO', 'Region']].drop_duplicates().merge(aglo_labels)

data = pd.read_csv('./../data/pobreza'+str(frac)+'.csv', index_col=0)
# data = pd.read_csv('./../data/pobreza'+str(frac)+'_2019.csv', index_col=0)
data = data.merge(radio_ref, on = ['RADIO_REF_ID', 'AGLOMERADO'])
data['AGLO_si'] = data.AGLOMERADO != 0

pob_tot = len(data)/frac/yrs_pob_data
# pob_tot

# %% [markdown]
# # Ingresos de hogares, pobreza e indigencia. (Argentina)
#
# Matias Iglesias
#
# matuteiglesias@gmail.com

# %% [markdown]
# # Introducción.
#
# Este reporte presenta estimaciones de ingreso medio de hogares y personas en todo el territorio de la Republica Argentina a partir de la información en la Encuesta Permanente de Hogares (EPH) y el Censo de Población, Hogares y Viviendas de 2010, realizados por el Instituto Nacional de Estadística y Censos (INDEC).
#
# Explotando las variables en común contenidas en ambas fuentes se entrenan algoritmos de clasificación y regresión que predicen los ingresos de muestras sintéticas de la población total consultada en Censo. O sea *machine learning* aplicado al Censo y las encuestas de hogares. Esto permite obtener valores de ingresos, incidencia de pobreza e indigencia y otras variables socioeconómicas segun características demográficas y habitacionales de las provincias, areas metropolitanas, departamentos, partidos, comunas u otras areas censales detalladas.

# %%
# from IPython.display import Image
# Image("./mapa_portada.png")

# %% [markdown]
# # Contenido
# - Incidencia de pobreza e indigencia
# - Evolucion semestral
#
#     - Cantidades (miles)
#     - Porcentajes
#
# - Ingresos a precios constantes (ARS 2019Q2)
#     - Deciles de ingreso
#     - Lineas de Pobreza e indigencia
#
# - Dependencia con otras variables
#     - Habitaciones de la vivienda
#     - Edad
#     - Niveles educativos
#
# - Dependencia geografica
#     - Variacion regional
#     - Por departamento y fraccion censal
#     - Por Provincia
#     - Por Region y aglomerado
#     - Partidos y Comunas del AMBA
#
# - Evolucion temporal por areas especificas.
#
# - Lista de Aglomerados

# %% [markdown]
# # Incidencia de pobreza e indigencia
# ## Total Pais

# %%
pd.read_csv('./../data/cuadro4_'+str(frac)+'_ARG', index_col=[0, 1], header = [0, 1, 2]).tail(10).T
# Out:
# Q                                      2017-12-31 2018-03-31 2018-06-30  \
# Total pais                                     Si         Si         Si
# CBA          mean   Hogares              15000.00   15000.00   14900.00
#              median Hogares              14200.00   14100.00   13900.00
# CBT          mean   Hogares              36900.00   37600.00   37600.00
#              median Hogares              34900.00   35400.00   35200.00
# Indigencia   mean   Hogares                  5.55       5.31       6.01
#                     Mayores de 24            3.94       3.78       4.44
#                     Personas                 7.21       6.94       8.01
#              sum    Hogares                676.70     653.00     739.40
#                     Personas              2888.50    2814.40    3251.80
# P47T_hogar   mean   Hogares              75800.00   84400.00   70600.00
#              median Hogares              60100.00   66500.00   56900.00
# P47T_persona mean   Mayores de 24        36800.00   40900.00   34100.00
#              median Mayores de 24        30100.00   31700.00   28400.00
# Pobreza      mean   Hogares                 20.85      19.30      23.90
#                     Mayores de 24           18.46      16.84      21.45
#                     Personas                28.41      26.36      32.03
#              sum    Hogares               2543.50    2374.80    2941.40
#                     Personas             11377.00   10696.00   12996.00
# gap          mean   Hogares              38900.00   46800.00   33100.00
#                     Hogares en pobreza  -20000.00  -20800.00  -20100.00
#              median Hogares              26600.00   31700.00   23300.00
#                     Hogares en pobreza  -15900.00  -16400.00  -15800.00
#
# Q                                      2018-09-30 2018-12-31 2019-03-31  \
# Total pais                                     Si         Si         Si
# CBA          mean   Hogares              15200.00   15700.00   15700.00
#              median Hogares              14300.00   14600.00   14700.00
# CBT          mean   Hogares              37900.00   38900.00   38900.00
#              median Hogares              35500.00   36500.00   36600.00
# Indigencia   mean   Hogares                  6.51       7.42       7.53
#                     Mayores de 24            4.77       5.61       5.68
#                     Personas                 8.49       9.94      10.23
#              sum    Hogares                801.30     913.00     934.20
#                     Personas              3443.40    4032.60    4183.90
# P47T_hogar   mean   Hogares              76200.00   64200.00   72800.00
#              median Hogares              59700.00   51900.00   55600.00
# P47T_persona mean   Mayores de 24        36800.00   30900.00   35600.00
#              median Mayores de 24        29500.00   26000.00   27000.00
# Pobreza      mean   Hogares                 22.68      27.67      26.39
#                     Mayores de 24           20.06      25.30      24.04
#                     Personas                30.37      36.57      35.35
#              sum    Hogares               2790.80    3405.40    3275.40
#                     Personas             12324.40   14837.30   14454.10
# gap          mean   Hogares              38400.00   25300.00   33900.00
#                     Hogares en pobreza  -21300.00  -21400.00  -22200.00
#              median Hogares              25700.00   16600.00   20900.00
#                     Hogares en pobreza  -17200.00  -16900.00  -18100.00
#
# Q                                      2019-06-30 2019-09-30 2019-12-31  \
# Total pais                                     Si         Si         Si
# CBA          mean   Hogares              15400.00   15400.00   15400.00
#              median Hogares              14400.00   14400.00   14400.00
# CBT          mean   Hogares              38500.00   38400.00   38300.00
#              median Hogares              36100.00   36000.00   35900.00
# Indigencia   mean   Hogares                  7.77       7.35       8.24
#                     Mayores de 24            5.87       5.44       6.34
#                     Personas                10.39       9.82      11.46
#              sum    Hogares                964.60     912.40    1022.60
#                     Personas              4249.00    4016.20    4684.00
# P47T_hogar   mean   Hogares              62500.00   71000.00   60100.00
#              median Hogares              48700.00   55100.00   47500.00
# P47T_persona mean   Mayores de 24        30400.00   34800.00   29400.00
#              median Mayores de 24        24300.00   27600.00   24400.00
# Pobreza      mean   Hogares                 29.63      26.21      30.77
#                     Mayores de 24           27.21      23.66      28.48
#                     Personas                38.98      34.70      40.49
#              sum    Hogares               3677.40    3252.70    3819.40
#                     Personas             15937.00   14188.20   16552.00
# gap          mean   Hogares              24000.00   32600.00   21800.00
#                     Hogares en pobreza  -21000.00  -21400.00  -21500.00
#              median Hogares              15400.00   20300.00   13800.00
#                     Hogares en pobreza  -16800.00  -17200.00  -17200.00
#
# Q                                      2020-03-31
# Total pais                                     Si
# CBA          mean   Hogares              15900.00
#              median Hogares              14900.00
# CBT          mean   Hogares              38500.00
#              median Hogares              36300.00
# Indigencia   mean   Hogares                  7.37
#                     Mayores de 24            5.44
#                     Personas                 9.90
#              sum    Hogares                922.60
#                     Personas              4076.90
# P47T_hogar   mean   Hogares              71100.00
#              median Hogares              56600.00
# P47T_persona mean   Mayores de 24        35000.00
#              median Mayores de 24        28600.00
# Pobreza      mean   Hogares                 26.40
#                     Mayores de 24           23.50
#                     Personas                34.98
#              sum    Hogares               3306.40
#                     Personas             14406.00
# gap          mean   Hogares              32600.00
#                     Hogares en pobreza  -21300.00
#              median Hogares              21700.00
#                     Hogares en pobreza  -17200.00

# %%
# df = pd.read_csv('./../data/cuadro_'+str(frac)+'_Total_pais_Q_n_ARG', index_col=[0, 1], header = [0, 1]).drop_duplicates().unstack(0, 1)
# df.index = pd.to_datetime(df.index)

# df_ = df[['Indigencia', 'Pobreza']].groupby(pd.Grouper(level = 0, freq = '6MS')).mean().T
# n = df_.copy()
# n.columns = n.columns.to_period("6M")

# df = pd.read_csv('./../data/cuadro_'+str(frac)+'_Total_pais_Q_pct_ARG', index_col=[0, 1], header = [0, 1]).drop_duplicates().unstack(0, 1)
# df.index = pd.to_datetime(df.index)

# df_ = df[['Indigencia', 'Pobreza']].groupby(pd.Grouper(level = 0, freq = '6MS')).mean().T
# pct = df_.copy()
# pct.columns = pct.columns.to_period("6M")


# total_pais = pd.concat([pd.DataFrame(n.iloc[:, -1]),
#                         pd.DataFrame(pct.iloc[:, -1])], axis = 1)
# total_pais.columns = ['Cantidad (miles)', 'Porcentaje']

# x = total_pais
# x.index = x.index.droplevel(2)

cuadro5 = pd.read_csv('./../data/cuadro4_'+str(frac)+'_ARG', index_col=[0, 1], header = [0, 1, 2])
df = cuadro5.iloc[:, cuadro5.columns.get_level_values(0).isin(['Indigencia', 'Pobreza'])
            & cuadro5.columns.get_level_values(2).isin(['Hogares', 'Personas'])]

# Leave just time as index
df = df.unstack()

df.index = pd.DatetimeIndex(df.index)

# Ultimo periodo
x = df.iloc[-1].unstack([3, 1])
x.columns = ['Porcentaje', 'Cantidad (miles)']

# Rolling 4 trimestres de interpolado
df = df.resample('Q').mean().interpolate().rolling(4).mean()

x.round({'Cantidad (miles)': -2, 'Porcentaje': 1}).sort_index()
# Out:
#                      Porcentaje  Cantidad (miles)
# Indigencia Hogares          7.4             900.0
#            Personas         9.9            4100.0
# Pobreza    Hogares         26.4            3300.0
#            Personas        35.0           14400.0

# %%
md("En el primer trimestre de 2019, la pobreza alcanza el {:.0f}".format(x.loc[('Pobreza', 'Hogares')].Porcentaje)+"% \
   de los hogares, donde viven el {:.0f}".format(x.loc[('Pobreza', 'Personas')].Porcentaje)+"% de las personas ({:.1f}".format(0.001*x.loc[('Pobreza', 'Personas')]['Cantidad (miles)'])+" millones). \
   La indigencia en el mismo periodo alcanza al {:.1f}".format(x.loc[('Indigencia', 'Hogares')].Porcentaje)+"% de los hogares, en donde viven {:.1f}".format(0.001*x.loc[('Indigencia', 'Personas')]['Cantidad (miles)'])+" millones de\
   personas ({:.1f}".format(x.loc[('Indigencia', 'Personas')].Porcentaje)+"%)")
# Out:
# En el primer trimestre de 2019, la pobreza alcanza el 26%    de los hogares, donde viven el 35% de las personas (14.4 millones).    La indigencia en el mismo periodo alcanza al 7.4% de los hogares, en donde viven 4.1 millones de   personas (9.9%)

# %% [markdown]
# ## Evolucion Temporal

# %%
sns.set()

fig, ax = plt.subplots(1, figsize = (10, 7))

# Series
df_ = df.iloc[:, df.columns.get_level_values(1) == 'mean']
df_ = df_.T.reindex(df_.T.sum(1).sort_values(ascending = False).index).T
df_.columns = df_.columns.droplevel([1, 3])
df_.plot(ax = ax, marker = '.')


# df_2 = cuadro3.iloc[:, cuadro3.columns.get_level_values(0).isin(['Indigencia', 'Pobreza'])
#             & cuadro5.columns.get_level_values(2).isin(['Hogares', 'Personas']) & (cuadro5.columns.get_level_values(1) == 'mean')]
# df_2 = df_2.loc[df_2.index.get_level_values(1) == True]
# # Leave just time as index
# df_2 = df_2.unstack()
# df_2.index = pd.DatetimeIndex(df_2.index)
# df_2.columns = df_2.columns.droplevel([1, 3])
# # Rolling 4 trimestres de interpolado
# df_2 = df_2.resample('Q').mean().interpolate().rolling(4).mean()
# df_2.plot(ax = ax, marker = '.')

# Plot
ax.legend(loc = (1.02,0))
ax.set_ylabel('Porcentajes')
ax.set_ylim(0, 70)
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 30, ha="left" )
ax.set_xlim(pd.Timestamp('2002-02-15'), pd.Timestamp('2019-07-01'))
ax.set_xlabel('Trimestre')
ax.legend(['Pobreza, personas', 'Pobreza, hogares', 
           'Indigencia, personas', 'Indigencia, hogares'])

# # ANADIR SERIE CEDLAS
# serie_cedlas = pd.read_csv('./../../data/tornarolli_cedlas.csv', index_col=[0, 1], header = [0, 1])
# serie_cedlas = serie_cedlas.T[serie_cedlas.columns.get_level_values(1) == 'Comparable'].T
# serie_cedlas.columns = serie_cedlas.columns.get_level_values(0)
# serie_cedlas.index = pd.date_range("2003-09", periods=len(serie_cedlas), freq = '6M')
# (1.*serie_cedlas).plot(color = '.6', marker = '+', ax = ax)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-78-07b7b1b44fb6> in <module>()
#      32
#      33 # ANADIR SERIE CEDLAS
# ---> 34 serie_cedlas = pd.read_csv('./../../data/tornarolli_cedlas.csv', index_col=[0, 1], header = [0, 1])
#      35 serie_cedlas = serie_cedlas.T[serie_cedlas.columns.get_level_values(1) == 'Comparable'].T
#      36 serie_cedlas.columns = serie_cedlas.columns.get_level_values(0)
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'./../../data/tornarolli_cedlas.csv' does not exist: b'./../../data/tornarolli_cedlas.csv'

# %% [markdown]
# Los puntos de este gráfico son los **valores promedios de los últimos 4 trimestres**. Previo a ese cálculo se interpola linealmente para tener los valores de los trimestres 2007-Q3, 2015-Q3, 2015-Q4, y 2016-Q1 para los cuales el INDEC no ofrece bases de microdatos.
#
# En los últimos 15 años hay una tendencia de **descenso** de los niveles de pobreza.
#
# ***El dilema de 'Los numeros del INDEC'***
#
# Existe un cuestionamiento de las series de índice de precios ofrecidas por INDEC entre 2007 y 2015. Los cálculos de los niveles de pobreza dependen de los valores en términos reales de las canastas alimentarias.
#
# En este trabajo:
#    * Se usan las canastas alimentaria y total regionales establecidas por INDEC desde 2016.
#    * Construimos un indice de precios mensual de consenso entre las multiples mediciones disponibles en cada periodo.
#    * El valor medio de las canastas de INDEC post 2016, a precios constantes se usa para los años anteriores.
#
# De esta forma tenemos una regla fija para los niveles de pobreza en todo el período, **independiente de los índices de precios elaborados por INDEC**.

# %% [markdown]
# ## Separacion 'aglomerados' vs resto del pais

# %%
#md("Los indicadores mas usados en determinar incidencia de pobreza se restringen a los llamados áglomerados urbanos'. La cifra de {:.0f}".format(x.loc[('Pobreza', 'Personas')].Porcentaje)+"% de las personas en pobreza difiere del 32.0% reportado por INDEC para el segundo semestre de 2018 los 33,6% reportados en el informe de UCA para 2018-Q3, principalmente por incluir la poblacion que vive fuera de los aglomerados urbanos.")

# %% [markdown]
# ***La Encuesta de Hogares no releva zonas rurales***
#
# El INDEC publica en informes semestrales los principales indicadores de pobreza e indigencia. La fuente primaria de información para ellos es la encuesta de hogares EPH. Sin embargo, esta última releva sólamente aglomerados urbanos grandes, dejando en un punto ciego al casi 9% de la poblacion que vive en zona rural, ademas de otro 25% de las personas y hogares que no pertenecen a los aglomerados grandes.

# %% [markdown]
# ### Porcentajes
# #### Niveles

# %%
# df = pd.read_csv('./../data/cuadro_'+str(frac)+'_AGLO_si_Q_pct_ARG', index_col=[0, 1], header = [0, 1]).drop_duplicates().unstack(0, 1)
# df.index = pd.to_datetime(df.index)

# df_ = df[['Indigencia', 'Pobreza']].groupby(pd.Grouper(level = 0, freq = '6MS')).mean().T
# df_.index = pd.MultiIndex.from_tuples([(x[0], x[1], 'Aglomerados' if x[2] else 'Resto') for x in df_.index])
# show = df_.copy()
# show.columns = show.columns.to_period("6M")
# show = show.interpolate(axis = 1)

# show.round(1).style.set_properties(**{'color': 'gray'}, subset=[show.columns[3]])


# # error relativo 0.01

# %%
cuadro3 = pd.read_csv('./../data/cuadro2_'+str(frac)+'_ARG', index_col=[0, 1], header = [0, 1, 2])
df = cuadro3.iloc[:, cuadro5.columns.get_level_values(0).isin(['Indigencia', 'Pobreza'])
            & cuadro5.columns.get_level_values(2).isin(['Hogares', 'Personas'])
                 & cuadro5.columns.get_level_values(1).isin(['mean'])]

# Leave just time as index
df = df.unstack()

df.index = pd.DatetimeIndex(df.index)

# Ultimo periodo
x = df.iloc[-1].unstack([3, 1])
x.columns = ['Fuera de aglomerados', 'Aglomerados']

x.round(1)
# Out:
#                      Fuera de aglomerados  Aglomerados
# Indigencia Hogares                    9.8          6.1
#            Personas                  13.3          8.0
# Pobreza    Hogares                   32.1         23.4
#            Personas                  42.3         30.9

# %% [markdown]
# ***Posible sobreestimacion de pobreza rural***
#
# A la espera de una mejor solución (es decir, que se implemente un muestreo directo de la poblacion fuera de aglomerados), asumimos que ésta es equivalente a la relevada en los centros urbanos. Ciertamente esto puede conllevar a errores sistemáticos. por dar un ejemplo, el nivel educativo en las zonas rurales es significativamente menor. En la ciudad este es un signo de peores condiciones de trabajo e ingresos, pero no necesariamente esto es así en un entorno rural.
#
# Si nos basamos en niveles educativos podríamos facilmente sobreestimar la pobreza rural, y por lo tanto el total nacional.
# Al presentar los resultados desagregados geograficamente este tema puede salvarse.

# %%
startyr = 2003
endyr = 2021

# %% [markdown]
# ***Serie Temporal***

# %%
# Rolling 4 trimestres de interpolado
df = df.resample('Q').mean().interpolate()

show = df.groupby(pd.TimeGrouper('Y', level = 0)).mean()
show.columns = show.columns.droplevel(1)
show.index = range(startyr, endyr)

show.columns = pd.MultiIndex.from_tuples([(x[0], x[1], 'Aglomerados' if x[2] else 'Resto') for x in show.columns])

show.T.round(1)
# Out:
#                                  2003  2004  2005  2006  2007  2008  2009  \
# Indigencia Hogares  Resto        24.2  22.5  19.8  16.2  13.8  12.7  12.3
#                     Aglomerados  14.7  13.7  11.4   9.1   7.7   7.0   6.7
#            Personas Resto        31.8  29.8  26.6  21.7  18.5  17.4  16.5
#                     Aglomerados  19.4  18.3  15.3  12.2  10.2   9.3   8.8
# Pobreza    Hogares  Resto        55.2  52.4  48.7  41.6  38.0  36.3  34.8
#                     Aglomerados  39.6  38.2  34.4  28.8  26.1  24.2  23.1
#            Personas Resto        64.4  61.9  58.7  51.2  47.7  46.2  44.2
#                     Aglomerados  48.2  47.4  43.0  36.9  34.2  31.8  30.3
#
#                                  2010  2011  2012  2013  2014  2015  2016  \
# Indigencia Hogares  Resto        11.1   9.8   9.4   8.6   8.9   7.9   8.4
#                     Aglomerados   5.9   5.4   5.5   5.1   5.5   5.0   5.6
#            Personas Resto        15.0  13.4  12.6  11.5  11.9  10.4  11.0
#                     Aglomerados   7.8   7.2   7.1   6.5   7.0   6.3   6.9
# Pobreza    Hogares  Resto        33.9  31.1  30.0  28.0  29.9  27.5  28.2
#                     Aglomerados  22.4  20.6  20.7  19.4  20.7  19.5  20.2
#            Personas Resto        43.2  40.9  39.2  37.3  39.7  36.6  37.0
#                     Aglomerados  29.4  27.5  27.6  26.0  27.7  26.1  26.7
#
#                                  2017  2018  2019  2020
# Indigencia Hogares  Resto         7.7   8.4  10.2   9.8
#                     Aglomerados   4.8   5.2   6.4   6.1
#            Personas Resto        10.3  11.4  14.1  13.3
#                     Aglomerados   6.2   6.6   8.4   8.0
# Pobreza    Hogares  Resto        25.9  29.0  34.3  32.1
#                     Aglomerados  18.0  20.4  25.0  23.4
#            Personas Resto        35.0  38.6  44.9  42.3
#                     Aglomerados  24.3  27.3  33.2  30.9

# %%
show = df.diff(4).groupby(pd.TimeGrouper('Y', level = 0)).mean()
show.columns = show.columns.droplevel(1)
show.index = range(startyr, endyr)
show.columns = pd.MultiIndex.from_tuples([(x[0], x[1], 'Aglomerados' if x[2] else 'Resto') for x in show.columns])


show.T.round(1).style.applymap(color_negative_red)
# Out:
# <style  type="text/css" >
#     #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col0 {
#             color:  black;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col1 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col2 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col3 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col4 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col5 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col6 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col7 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col8 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col9 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col10 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col11 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col12 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col13 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col14 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col15 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col16 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row0_col17 {
#             color:  black;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col0 {
#             color:  black;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col1 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col2 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col3 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col4 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col5 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col6 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col7 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col8 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col9 {
#             color:  black;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col10 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col11 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col12 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col13 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col14 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col15 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col16 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row1_col17 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col0 {
#             color:  black;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col1 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col2 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col3 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col4 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col5 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col6 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col7 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col8 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col9 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col10 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col11 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col12 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col13 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col14 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col15 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col16 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row2_col17 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col0 {
#             color:  black;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col1 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col2 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col3 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col4 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col5 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col6 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col7 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col8 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col9 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col10 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col11 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col12 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col13 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col14 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col15 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col16 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row3_col17 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col0 {
#             color:  black;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col1 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col2 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col3 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col4 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col5 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col6 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col7 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col8 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col9 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col10 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col11 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col12 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col13 {
#             color:  red;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col14 {
#             color:  green;
#         }    #T_20c7d7ea_3975_11eb_aaf2_5ce0c5892623row4_col15 {

# %% [markdown]
# El ultimo minimo para todas las series de pobreza e indigencia se da en el segundo semestre de 2017.

# %% [markdown]
# ### Cantidades (miles)
# ### Niveles

# %%
# # Escala crecimiento poblacional para cantidades... No se usa mas porque ahora los archivos ya vienen escalados

# escala = pd.read_csv('./../data/escala_poblacion.csv')
# escala.index = pd.DatetimeIndex(pd.date_range(start = '2010', freq='Y', periods = len(escala))+ pd.DateOffset(days=-184) )
# escala = escala[['r2018']].resample('6M').interpolate().loc['2014':'2018']

# %%
# md("En el tercer trimestre de 2018, la pobreza alcanza {:.1f}".format(0.001*x.loc[('Pobreza', 'Personas')]['Cantidad (miles)'])+" millones de personas en todo el pais. \
#    \n\
#    La indigencia en el mismo periodo alcanza {:.1f}".format(0.001*x.loc[('Indigencia', 'Personas')]['Cantidad (miles)'])+" millones de personas\
#    \n\
#    A continuación la desagregacion entre aglomerados y resto del país. ")

# %%
# df = pd.read_csv('./../data/cuadro_'+str(frac)+'_AGLO_si_Q_n_ARG', index_col=[0, 1], header = [0, 1]).drop_duplicates().unstack(0, 1)
# df.index = pd.to_datetime(df.index)

# df_ = df[['Indigencia', 'Pobreza']].groupby(pd.Grouper(level = 0, freq = '6MS')).mean().T
# df_.index = pd.MultiIndex.from_tuples([(x[0], x[1], 'Aglomerados' if x[2] else 'Resto') for x in df_.index])
# show = df_.copy()
# show = (show.T*escala.values).T
# show.columns = show.columns.to_period("6M")
# show = show.interpolate(axis = 1)

# myround(show, 20).style.set_properties(**{'color': 'gray'}, subset=[show.columns[3]])


# # Redondear en decenas de miles? al menos..

# %%
cuadro3 = pd.read_csv('./../data/cuadro2_'+str(frac)+'_ARG', index_col=[0, 1], header = [0, 1, 2])
df = cuadro3.iloc[:, cuadro5.columns.get_level_values(0).isin(['Indigencia', 'Pobreza'])
            & cuadro5.columns.get_level_values(2).isin(['Hogares', 'Personas'])
                 & cuadro5.columns.get_level_values(1).isin(['sum'])]

# Leave just time as index
df = df.unstack()

df.index = pd.DatetimeIndex(df.index)

# Ultimo periodo
x = df.iloc[-1].unstack([3, 1])
x.columns = ['Fuera de aglomerados', 'Aglomerados']

# myround(x, 20).astype(int)
# Error es 10mil en pobreza hogares, 50mil en pobreza personas

# %% [markdown]
# ***Serie Temporal***

# %%
# Rolling 4 trimestres de interpolado
df = df.resample('Q').mean().interpolate()

show = df.groupby(pd.TimeGrouper('Y', level = 0)).mean()
show.columns = show.columns.droplevel(1)
show.index = range(startyr, endyr)

myround(show.T, 20).astype(int)
# Out:
#                               2003   2004  2005  2006  2007  2008  2009  2010  \
#                     AGLO_si
# Indigencia Hogares  False     1000    920   800   660   560   520   520   460
#                     True      1060   1000   800   640   560   520   500   440
#            Personas False     4400   4140  3620  2980  2560  2420  2340  2140
#                     True      4500   4280  3480  2800  2360  2200  2120  1880
# Pobreza    Hogares  False     2260   2160  1960  1680  1560  1500  1460  1420
#                     True      2840   2760  2440  2060  1880  1780  1700  1660
#            Personas False     8900   8600  7980  7040  6600  6440  6260  6160
#                     True     11160  11080  9820  8520  7980  7520  7260  7100
#
#                              2011  2012  2013  2014  2015  2016  2017  2018  \
#                     AGLO_si
# Indigencia Hogares  False     420   400   380   400   360   380   320   360
#                     True      400   420   400   420   400   440   380   420
#            Personas False    1940  1840  1700  1780  1580  1680  1480  1660
#                     True     1760  1760  1620  1740  1620  1780  1580  1740
# Pobreza    Hogares  False    1320  1300  1220  1320  1220  1260  1100  1240
#                     True     1560  1580  1480  1600  1540  1600  1440  1640
#            Personas False    5900  5760  5540  5920  5560  5700  5000  5600
#                     True     6720  6820  6460  6960  6640  6880  6280  7120
#
#                              2019  2020
#                     AGLO_si
# Indigencia Hogares  False     440   420
#                     True      520   500
#            Personas False    2060  1960
#                     True     2220  2120
# Pobreza    Hogares  False    1480  1400
#                     True     2020  1900
#            Personas False    6580  6240
#                     True     8700  8160

# %%
show = df.diff(4).groupby(pd.TimeGrouper('Y', level = 0)).mean()
show.columns = show.columns.droplevel(1)
show.index = range(startyr, endyr)

show.T.round(-1).style.applymap(color_negative_red)
# Out:
# <style  type="text/css" >
#     #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col0 {
#             color:  black;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col1 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col2 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col3 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col4 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col5 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col6 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col7 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col8 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col9 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col10 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col11 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col12 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col13 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col14 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col15 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col16 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row0_col17 {
#             color:  black;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col0 {
#             color:  black;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col1 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col2 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col3 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col4 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col5 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col6 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col7 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col8 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col9 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col10 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col11 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col12 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col13 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col14 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col15 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col16 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row1_col17 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col0 {
#             color:  black;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col1 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col2 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col3 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col4 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col5 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col6 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col7 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col8 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col9 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col10 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col11 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col12 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col13 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col14 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col15 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col16 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row2_col17 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col0 {
#             color:  black;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col1 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col2 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col3 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col4 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col5 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col6 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col7 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col8 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col9 {
#             color:  black;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col10 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col11 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col12 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col13 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col14 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col15 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col16 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row3_col17 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col0 {
#             color:  black;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col1 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col2 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col3 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col4 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col5 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col6 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col7 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col8 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col9 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col10 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col11 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col12 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col13 {
#             color:  red;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col14 {
#             color:  green;
#         }    #T_2134c6f2_3975_11eb_aaf2_5ce0c5892623row4_col15 {

# %%
nuevos_pobres = show.iloc[-4:]['Pobreza']['Personas'].sum().sum()
nuevos_indigs = show.iloc[-4:]['Indigencia']['Personas'].sum().sum()

md()
    
"Las estimaciones dan cuenta que en 2019 habrá {:.1f}".format(0.001*nuevos_pobres)+" millones de pobres más que en 2015. \
Además habrá {:.1f}".format(0.001*nuevos_indigs)+" millones de nuevos indigentes. Los niveles de pobreza en 2019 igualan a los de 2008."
# Out:
# 'Las estimaciones dan cuenta que en 2019 habrá 2.7 millones de pobres más que en 2015. Además habrá 0.7 millones de nuevos indigentes. Los niveles de pobreza en 2019 igualan a los de 2008.'

# %% [markdown]
# ## Ingresos a precios constantes (ARS 2019-Q4)
#
# Los valores monetarios reportados son en todos los casos en pesos argentinos (AR$) a valores constantes de 2019-Q4.

# %% [markdown]
# ### Percentiles de ingreso
# (Personas mayores de 24)

# %%
# #JIC

# import pandas as pd
# import matplotlib.pyplot as plt
# %matplotlib inline
# import seaborn as sns

# import numpy as np

# from IPython.display import Markdown as md

# import numpy as np
# from matplotlib.ticker import EngFormatter

# data = pd.read_csv('./../data/pobreza'+str(frac)+'.csv', index_col=0)
# data.nunique()

# %%
# import numpy as np
# s, bins_persona = pd.qcut(data.loc[data.P03 > 24].P47T_persona, 9, retbins=True, duplicates = 'drop')
# s, bins_hogares = pd.qcut(data.groupby('HOGAR_REF_ID').first().P47T_hogar, 9, retbins=True)
# df = pd.DataFrame([bins_persona[1:-1], bins_hogares[1:-1]], index = ['Ingreso Persona', 'Ingreso Hogar']).T
# # df.index = np.array([ 1, 2,  3,  4,  'mediana', 6,  7,  8,  9])
# # myround(df, 250).astype(int)
# df
# # Error +- 300 pe

# %%
def plot_dist(data, variable = 'P47T_hogar', xmin = 0, titulo = 'Title'):
    fig, ax = plt.subplots(1, figsize = (13, 6))

    no_pobres_hist = np.repeat(data.loc[data.Pobreza == False][['HOGAR_REF_ID', variable]].drop_duplicates()[variable].values, 1/frac/yrs_pob_data)
    pobres_hist = np.repeat(data.loc[(data.Pobreza) & (~data.Indigencia)][['HOGAR_REF_ID', variable]].drop_duplicates()[variable].values, 1/frac/yrs_pob_data)
    indig_hist = np.repeat(data.loc[data.Indigencia][['HOGAR_REF_ID', variable]].drop_duplicates()[variable].values, 1/frac/yrs_pob_data)
    hist_data = [indig_hist, pobres_hist, no_pobres_hist]
    plt.hist(hist_data, np.arange(xmin, 250000, 5000), stacked=True, alpha = .5)
    
    ax.legend(['Indigentes', 'Pobres no indigentes', 'No pobres'])
    ax.axvline(0, c = 'k')
    ax.yaxis.set_major_formatter(EngFormatter())

    plt.xlim(xmin, 250000)
    plt.ylim(0, 1e6)
    # plt.yscale('log')
    plt.ylabel('Cantidad \n total nacional por bin de AR$ 5000')
    plt.xlabel(titulo)

    plt.show()

# %%
import numpy as np
from matplotlib.ticker import EngFormatter

plot_dist(data.groupby('HOGAR_REF_ID').first().reset_index(), variable = 'P47T_hogar', xmin = 0, 
          titulo = 'Ingreso del hogar (AR$ 2019 Q4)')

# plot_dist(data.loc[(data['P03'] > 24) & (data['P03'] > 34)], variable = 'P47T_persona', xmin = 0, 
#           titulo = 'Ingreso del hogar (AR$ 2019 Q4)')

# %% [markdown]
# ## Lineas de Pobreza e indigencia

# %% [markdown]
# #### Total Pais

# %%
from IPython.display import display, HTML
# def pretty_print(df):
#     return display(HTML(df.to_html().replace("\\n","<br>")))

def pd_centered(df):
    return df.style.set_table_styles([
        {"selector": "th", "props": [("text-align", "center")]},
        {"selector": "td", "props": [("text-align", "center")]}])

# %%
# tabla_semestral = pd.read_csv('./../data/tabla_semestral.csv', index_col=0, header = [0, 1])
# table = tabla_semestral.drop(['PERSONA_REF_ID', 'CBA','CBT'], axis = 1)
# table = table.iloc[:, table.columns.get_level_values(1) != 'sum']
# table.index = pd.to_datetime(table.index, infer_datetime_format=True)
# table.index = table.index.to_period("6M")

# table[('Pobreza', 'mean')] = 100*table[('Pobreza', 'mean')]
# table[('Indigencia', 'mean')] = 100*table[('Indigencia', 'mean')]

# table.columns = pd.Index([('Ingreso Persona', 'promedio'), ('Ingreso Persona', 'mediana'),
#                 ('Ingreso Hogar', 'promedio'), ('Ingreso Hogar', 'mediana'),
#                 ('Ingreso Hogar sobre linea de pobreza', 'promedio'), ('Ingreso Hogar sobre linea de pobreza', 'mediana'),
#                 ('Pobreza (personas)', '%'), ('Indigencia (personas)', '%')])

# pd_centered(table.round({('Ingreso Persona', 'promedio'): -2, ('Ingreso Persona', 'mediana'): -2,
#                 ('Ingreso Hogar', 'promedio'): -2, ('Ingreso Hogar', 'mediana'): -2,
#                 ('Ingreso Hogar sobre linea de pobreza', 'promedio'): -2, ('Ingreso Hogar sobre linea de pobreza', 'mediana'): -2,
#                 ('Pobreza (personas)', '%'): 1, ('Indigencia (personas)', '%'): 1}))

# %% [markdown]
# \* En este cuadro, el calculo de ingresos medios incluye a toda la poblacion, tambien menores e inactivos.
#
#
#
# ## 'Linea de Pobreza'
#
# Para este paso, se aplican la regla sugerida por INDEC de pobreza monetaria.
#
# **De donde sale***
#
# Involucra usar un numero cercano a 2.5 que viene de la encuesta de Gastos de Hogares (ENGHO).
# Es decir, esta es una linea de ~2.5 Canastas alimentarias. Este es un punto crucial ya que afecta el numerito final de resultado que vamos a tener. Los valores precisos van a estar en el apendix pero seria bueno tambien un calculo menos vulnerable al control.
# La canasta alimentaria al poder ser biologicamente establecida y con algunos estimadores economicos sencillos (cuanto cuesta comer lo necesario) es mas transparente. Tambien se presta a ser comparada en reglas internacionales, es decir sugerencias de valores PPP que representan un nivel medido de alimentacion.
#
# ***Como se calcula***
#  - Se usan los 10 trimestres disponibles para entrenar.
#  - Los resultados del algoritmo de prediccion son ingresos de personas y hogares.
#  - Nos permite predecir un output complicado, como puede ser una condicion en la ecuacion del hogar.
#  - Aprovechamos que los ponderamientos se pueden lograr sampleando al azar de una muestra comprensiva (Censo 2010).
#  - Se usan las proyecciones poblacionales por departamento (INDEC)
#  - Todos los valores en pesos de 2019-Q4. Conviene deflactar mensualmente.
#  - Se usa promedio simple. En alta inflacion da cierto bias. Aunque igualmente, tambien nosotros perdemos idea de cuanto valia el peso en ese momento.

# %%
plot_dist(data, variable = 'gap_pobreza', xmin = -50000,
          titulo = 'Ingreso del hogar por sobre Canasta Total \n "Linea de pobreza" \n (AR$ 2019 Q4)')

# %% [markdown]
# ***La linea de la canasta alimentaria***

# %%
plot_dist(data, variable = 'gap_indigencia', xmin = -25000,
          titulo = 'Ingreso del hogar por sobre Canasta Alimentaria \n "Linea de indigencia" \n (AR$ 2019 Q4)')

# %% [markdown]
# Una vez que se hacen predicciones de ingresos y se calcula la 'Canasta Basica Alimentaria' de las personas de los hogares, calculamos la ecuacion en cada uno de los hogares y agregamos los resultados.
#
# Esto nos deja ver una estructura detallada de la población de hogares que no llega pagar la canasta básica alimentaria de sus integrantes.

# %% [markdown]
# #### Canastas alimentaria y total, vs ingreso medio individual y de hogar.
#
# Precios constantes de 2019-Q4. Los costos de canastas definidos post intervencion de 2016 se extienden hacia atras hasta 2003 para todos los calculos de pobreza.

# %%
# tabla_semestral_AGLOS = pd.read_csv('./../data/tabla_semestral_AGLOS.csv', index_col=0, header = [0, 1])
# table = tabla_semestral_AGLOS.drop(['PERSONA_REF_ID', 'CBA','CBT'], axis = 1)
# table = table.iloc[:, table.columns.get_level_values(1) != 'sum']
# table.index = pd.to_datetime(table.index, infer_datetime_format=True)
# table.index = table.index.to_period("6M")

# table[('Pobreza', 'mean')] = 100*table[('Pobreza', 'mean')]
# table[('Indigencia', 'mean')] = 100*table[('Indigencia', 'mean')]

# table.columns = pd.Index([('Ingreso Persona', 'promedio'), ('Ingreso Persona', 'mediana'),
#                 ('Ingreso Hogar', 'promedio'), ('Ingreso Hogar', 'mediana'),
#                 ('Ingreso Hogar sobre linea de pobreza', 'promedio'), ('Ingreso Hogar sobre linea de pobreza', 'mediana'),
#                 ('Pobreza (personas)', '%'), ('Indigencia (personas)', '%')])

# pd_centered(table.round({('Ingreso Persona', 'promedio'): -2, ('Ingreso Persona', 'mediana'): -2,
#                 ('Ingreso Hogar', 'promedio'): -2, ('Ingreso Hogar', 'mediana'): -2,
#                 ('Ingreso Hogar sobre linea de pobreza', 'promedio'): -2, ('Ingreso Hogar sobre linea de pobreza', 'mediana'): -2,
#                 ('Pobreza (personas)', '%'): 1, ('Indigencia (personas)', '%'): 1}))

# %%
cuadro5 = pd.read_csv('./../data/cuadro4_'+str(frac)+'_ARG', index_col=[0, 1], header = [0, 1, 2])
df = cuadro5.iloc[:, cuadro5.columns.get_level_values(0).isin(['CBA', 'CBT', 'P47T_hogar', 'P47T_persona', 'gap', ])
                 & cuadro5.columns.get_level_values(1).isin(['median', ])]

# Leave just time as index
df = df.unstack()

df.index = pd.DatetimeIndex(df.index)

# Rolling 4 trimestres de interpolado
df = df.resample('Q').mean().interpolate()

show = df.groupby(pd.TimeGrouper('Y', level = 0)).mean()
show.columns = show.columns.droplevel([1, 3])
show.columns = [('Canasta basica', 'alimentaria'), ('Canasta basica', 'total'), 
                ('Ingreso medio', 'hogar'), ('Ingreso medio', 'persona'),
                ('Brecha de hogares', 'todos'), ('Brecha de hogares', 'en pobreza')]
show.index = range(startyr, endyr)

# pd_centered(myround(show, 100).astype(int))

# %%
fig, ax = plt.subplots(figsize = (8, 5))
show.iloc[:, :4].plot(ax = ax, marker = '.')
plt.ylim(0, 6e4)
plt.xlim(2002, 2020)
ax.legend(loc = (1, .7))
plt.show()

# %% [markdown]
# ## Variacion regional

# %%
# #JIC

# import pandas as pd
# import matplotlib.pyplot as plt
# %matplotlib inline
# import seaborn as sns

# import numpy as np

# from IPython.display import Markdown as md

# import numpy as np
# from matplotlib.ticker import EngFormatter

data = pd.read_csv('./../data/pobreza'+str(frac)+'.csv', index_col=0)
# data = pd.read_csv('./../data/pobreza'+str(frac)+'_2019.csv', index_col=0)

# data.nunique()

aglo_labels = pd.read_csv('./../data/aglo_labels.csv')[['AGLOMERADO', 'NOMAGLO']]
radio_ref = pd.read_csv('./../data/radio_ref.csv').merge(aglo_labels)
dpto_region = pd.read_csv('./../data/DPTO_PROV_Region.csv')
radio_ref = radio_ref.merge(dpto_region)

# %%
data['NOMPROV'].nunique()
# Out:
# 23

# %%
### Matriz que da origen a las barritas de abajo.

data_hogares = data.groupby('HOGAR_REF_ID').first()
data_hogares = data_hogares.merge(radio_ref[['RADIO_REF_ID', 'Region', 'NOMPROV', 'NOMAGLO']].drop_duplicates())
data_hogares['Region'] = data_hogares['Region'].str.replace('Gran Buenos Aires', 'AMBA')
data_hogares['pctil'], bins_hogares = pd.qcut(data_hogares.P47T_hogar, 15, retbins=True)

df = data_hogares.groupby(['Region', 'pctil'])[['P47T_hogar']].count().unstack()
# df = df.div(df.sum(1), 0)#.round(3)

df_CABA = data_hogares.groupby(['NOMPROV', 'pctil'])[['P47T_hogar']].count().unstack().loc[['Ciudad Autónoma de Buenos Aires']]
# df_CABA = df_CABA.div(df_CABA.sum(1), 0)

df_GBA = data_hogares.groupby(['NOMAGLO', 'pctil'])[['P47T_hogar']].count().unstack().loc[['GBA']]
# df_GBA = df_GBA.div(df_GBA.sum(1), 0)

df = pd.concat([df_CABA, df_GBA, df])

df = df.reindex(['Noroeste', 'Noreste','Ciudad Autónoma de Buenos Aires', 'GBA', 'Cuyo', 'Pampeana', 'Patagónica'])

# %%
yrs_pob_data = 3

# %%
tot_reg = data_hogares.groupby('Region').count().iloc[:, 0]/frac/yrs_pob_data
totprovs = data_hogares.groupby('NOMPROV').count().iloc[:, 0]/frac/yrs_pob_data
totaglos = data_hogares.groupby('NOMAGLO').count().iloc[:, 0]/frac/yrs_pob_data

tot_hogares = pd.concat([tot_reg, totprovs, totaglos])

# %%
# Preparar gdf de pobreza por provincias

import geopandas as gpd
dptos_gdf = gpd.read_file('./../../../../../../../home/miglesia/Documents/censo_geo/pxdptodatosok.shp').drop([439])
dptos_gdf.crs = {'init': 'epsg:4326'} #latlong
dptos_gdf = dptos_gdf.to_crs({'init': 'epsg:3395'}) #lo dejamos en metrico

# %%
# dptos_gdf[['codpcia', 'provincia']].nunique()
# Out:
# codpcia      24
# provincia    24
# dtype: int64

# %%
provs_gdf = dptos_gdf[['codpcia', 'geometry']].dissolve('codpcia')
provs_gdf.index = provs_gdf.index.astype(int)

pob_prov = data.groupby('PROV')[['Pobreza']].mean()
ingreso_mediano = data.loc[data.P03 > 24].groupby('PROV')[['P47T_persona', 'P47T_hogar']].median()
nomprovs = radio_ref[['PROV', 'NOMPROV', 'Region']].drop_duplicates().set_index('PROV')

provs_gdf = gpd.GeoDataFrame(pd.concat([nomprovs, ingreso_mediano, pob_prov, provs_gdf], axis = 1))

fancy_crs = {u'lat_0': -35,
 u'lon_0': -65,
 u'no_defs': True,
 u'proj': u'ortho',
 u'units': u'm',
 u'x_0': -65,
 u'y_0': -35,
 u'a' : 6371000, 
 u'b' : 6371000}
provs_gdf.crs = {'init': 'epsg:3395'}
provs_gdf = provs_gdf.to_crs({'init': 'epsg:4326'})
provs_gdf = provs_gdf.to_crs(fancy_crs)

# %%
# gpd.GeoDataFrame(pd.concat([nomprovs, ingreso_mediano, pob_prov, provs_gdf], axis = 1))
# pob_prov
# Out:
# (23, 1)

# %% [markdown]
# El cuadro de deciles de ingreso muestra valores nacionales. Sin embargo ¿Cómo se distribuyen las poblaciones regionales entre estos grupos de ingreso?

# %%
def myround(x, base=5):
    return base * round(x/base)
#     return base * (x/base).round()

# %%
import matplotlib.gridspec as gridspec

fig = plt.figure(constrained_layout=True, figsize = (16, 15))
spec = gridspec.GridSpec(ncols=2, nrows=len(df), figure=fig)

for i in range(len(df)):
#     ax = axs[i]
    ax = fig.add_subplot(spec[i, 0])
    (df.iloc[i]/yrs_pob_data).plot(kind = 'bar', ax = ax, width = .9, color = sns.color_palette("RdYlGn", 15), alpha = .8)# colormap = 'RdYlGn')
    lugar = df.index[i]
    ax.set_title(lugar + '.\n '+str('{:,}'.format(int(np.round(tot_hogares.loc[lugar], -3))).replace(',', '.'))+' hogares.')
    ax.set_xlabel('Percentiles nacionales de ingreso', fontsize = 10)
    ax.set_ylim(0, 13000)
    ax.axis('off')
    plt.subplots_adjust(hspace = 0.85)
    

ax = fig.add_subplot(spec[:, 1])
# provs_gdf.plot(column = 'P47T_persona', ax = ax, vmin = 10000, vmax = 35000, cmap = 'RdYlGn')
provs_gdf.plot(column = 'Pobreza', ax = ax, vmin = 0, vmax = .66, cmap = 'RdYlGn_r')

# Encuadre ARG
# ax.set_xlim(-8300000, -5750000)
# ax.set_ylim(-7450000, -2400000)
ax.set_xlim(-.75e6, 1.25e6)
ax.set_ylim(-2.3e6, 1.6e6)

# ax.set_xlabel('A')
ax.axis('off')

for i, row in provs_gdf.fillna(0).drop([90, 66]).iterrows():
    x = row.geometry.centroid.x
    y = row.geometry.centroid.y
    ingreso_mediano = '$'+str(int(myround(row.P47T_persona,500)))
#     ingreso_mediano = '$'#+str(row.P47T_persona,500)
    pobreza = str(int(round(100*row.Pobreza)))+'%'
#     ax.scatter(x, y, marker='x', color='red')
    ax.text(x, y + 40000, row.NOMPROV, fontsize=9, color = '.1', horizontalalignment = 'center')
    ax.text(x, y - 25000, pobreza, fontsize=11, color = '.1', horizontalalignment = 'center')
    ax.text(x, y - 70000, ingreso_mediano, fontsize=11, color = '.1', horizontalalignment = 'center')


# # regs_gdf.plot(color = 'None', edgecolor = 'k', ax = ax) Revisar
plt.title('Provincias.\n Personas en pobreza (%) \n ingreso mediano (mayores de 24)')
plt.show()

# fig.colorbar(im, ax=ax, orientation="horizontal")
# divider = make_axes_locatable(ax)
# cax = divider.new_vertical(size="5%", pad=0.7, pack_start=True)
# fig.add_axes(cax)
# fig.colorbar(im, cax=cax, orientation="horizontal")

# El error en ingreso medio por provincia esta en los 500 a 1000 pe
# En la cifra de pobreza el error es de 1%

# %%
xx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ce3af7760f12> in <module>()
# ----> 1 xx
#
# NameError: name 'xx' is not defined

# %%
import geopandas as gpd
dptos_gdf = gpd.read_file('./../../../../../../../home/miglesia/Documents/censo_geo/pxdptodatosok.shp').drop([439])
dptos_gdf['personas'] = pd.to_numeric(dptos_gdf['personas'])

data['link'] = data['DPTO'].astype(str).str.zfill(5)

pob_dpto = data.groupby('link')[['Pobreza']].mean().reset_index()

pob_dpto_gdf = gpd.GeoDataFrame(pob_dpto.merge(dptos_gdf))
# data.groupby('DPTO').count().iloc[:, 0].sort_values(ascending = False).head(10)

# pob_dpto_gdf.loc[pob_dpto_gdf.personas < 3000, 'Pobreza'] = np.nan
# pob_dpto_gdf = pob_dpto_gdf.fillna(pob_dpto_gdf.Pobreza.median())
# gdf = pob_dpto_gdf#.plot(column = 'Pobreza')

# fig, ax = plt.subplots(1, figsize = (6, 14))
# gdf.crs = {'init': 'epsg:4326'}
# gdf.to_crs({'init': 'epsg:3395'}).fillna(0).plot(column = 'Pobreza', ax = ax, vmin = -.1, vmax = .66, cmap = 'RdYlGn_r')
# plt.axis('off')
# plt.show()

# %% [markdown]
# ## Tamaño de la vivienda. Hacinamiento.

# %%
data = pd.read_csv('./../data/pobreza'+str(frac)+'.csv', index_col=0)
# data = pd.read_csv('./../data/pobreza'+str(frac)+'_2019.csv', index_col=0)


import numpy as np
from matplotlib.ticker import EngFormatter
# cat_cols = ['V01', 'H05', 'H06', 'H07', 'H08', 'H09', 'H10',
#        'H11', 'H12', 'H13', 'H14', 'H15', 'H16', 'PROP',
#        'P02', 'P05', 'P07', 'P08', 'P09', 'P10', 'CAT_OCUP',
#        'CAT_INAC', 'CH07', 'PP07G1', 'PP07G2', 'PP07G3', 'PP07G4', 'PP07G_59',
#        'PP07H', 'PP07I', 'PP07J', 'PP07K',
#        'AGLOMERADO', 'CONDACT', 'Grupo Etario'] # IX_TOT
# value_cols = 'P47T' #?

data['IX_TOT'] = np.clip(data.IX_TOT, 0, 10)
data['H15'] = np.clip(data.H15, 0, 9)

cat_cols = ['IX_TOT', 'H16', 'H15']

vn = pd.read_csv('./../data/VARIABLE_NAMES.csv')
# vn['Pregunta'] = vn['Pregunta'].str.strip()#.str.replace("'", "") Don't run
# data = data.reset_index().rename(columns = {'index': 'PERSONA_REF_ID'}) # parche porque no esta la columna

for cat in cat_cols:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))
    info = data.groupby([cat, 'Pobreza'])[['PERSONA_REF_ID', 'HOGAR_REF_ID']].nunique()
    info_pct = (100*(info.unstack()/info.unstack().sum()).stack())
    
    sns.barplot(x=cat, y="PERSONA_REF_ID", hue="Pobreza", data=(info/frac/yrs_pob_data).reset_index(), ax = ax1)
    xlab = ''
    try:
        xlab = vn.loc[vn.Censo == cat]['Pregunta'].values[0]
    except:
        try:
            xlab = vn.loc[vn.EPH == cat]['Pregunta'].values[0]
        except:
            pass
    ax1.set(xlabel= xlab, ylabel = 'cant de PERSONAS')
    ax1.yaxis.set_major_formatter(EngFormatter())
    sns.barplot(x=cat, y="HOGAR_REF_ID", hue="Pobreza", data=(info/frac/yrs_pob_data).reset_index(), ax = ax2)
    ax2.set(xlabel= xlab, ylabel = 'cant de HOGARES')
    ax2.yaxis.set_major_formatter(EngFormatter())
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-a3c9b4578d56> in <module>()
#      25 for cat in cat_cols:
#      26     fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))
# ---> 27     info = data.groupby([cat, 'Pobreza'])[['PERSONA_REF_ID', 'HOGAR_REF_ID']].nunique()
#      28     info_pct = (100*(info.unstack()/info.unstack().sum()).stack())
#      29
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/core/base.py in __getitem__(self, key)
#     263                 bad_keys = list(set(key).difference(self.obj.columns))
#     264                 raise KeyError("Columns not found: {missing}"
# --> 265                                .format(missing=str(bad_keys)[1:-1]))
#     266             return self._gotitem(list(key), ndim=2)
#     267
#
# KeyError: "Columns not found: 'PERSONA_REF_ID'"

# %% [markdown]
# ## Pobreza por grupo etario

# %%
# pd.cut(data.P03)

# %%
data['Grupo Etario'] = pd.cut(data.P03, np.arange(0, 90, 3))

cat = 'Grupo Etario'

vn = pd.read_csv('./../data/VARIABLE_NAMES.csv')
# vn['Pregunta'] = vn['Pregunta'].str.strip()#.str.replace("'", "") Don't run

fig, ax = plt.subplots(1, figsize = (15, 5))
info = data.groupby([cat, 'Pobreza'])[['PERSONA_REF_ID']].nunique()
sns.barplot(x=cat, y="PERSONA_REF_ID", hue="Pobreza", data=(info/frac/yrs_pob_data).reset_index(), ax = ax)
xlab = ''
ax.tick_params(axis='x', rotation=45)
ax.yaxis.set_major_formatter(EngFormatter())
ax.set(xlabel= xlab, ylabel = 'cant de PERSONAS')
plt.show()

# %%
# ## Upper tail

# data['income_bin'] = pd.cut(np.log10(data['P47T_persona']).replace(-np.inf, 1), 100)

# fig, ax = plt.subplots(1, figsize = (5, 6))

# pdf_info = data.groupby('income_bin')['PERSONA_REF_ID'].count().reset_index()
# pdf_info['PERSONA_REF_ID'] = pdf_info['PERSONA_REF_ID']/frac/yrs_pob_data

# pdf_info['pdf'] = pdf_info['PERSONA_REF_ID']/pdf_info['PERSONA_REF_ID'].sum()
# pdf_info['cdf'] = pdf_info['pdf'].cumsum()

# np.log10(1 - pdf_info.iloc[60:85].set_index('income_bin')[['cdf']]).reset_index().plot(x = 'income_bin', y = 'cdf', marker = '.', ax = ax)
# ax.tick_params(axis='x', rotation=45)

# pdf_info.tail(20)

# %% [markdown]
# ## Ingresos, pobreza e indigencia por niveles educativos
#
# En este cuadro, los ingresos medios, porcentaje de pobreza e indigencia segun nivel educativo.

# %%
cuadro = pd.read_csv('./../data/cuadro3_'+str(frac)+'_ARG', index_col=[0, 1], header = [0, 1, 2])
cuadro = cuadro.loc['2003':].drop(('P47T_persona', 'mean', 'Mayores de 24'), axis = 1)
cuadro.columns = ['Indigencia (%)', 'Ingresos (mediana)', 'Pobreza (%)']
cuadro = cuadro.unstack().mean().unstack().T

cuadro = cuadro[['Ingresos (mediana)', 'Pobreza (%)', 'Indigencia (%)']]
cuadro = cuadro.loc[[2, 20, 21, 40, 41, 60, 61, 70, 71, 80, 81]]

cuadro

data_sel = data[['P03','P0910']]
counts = data_sel.loc[data_sel.P03 > 24]['P0910'].value_counts()
counts_pct = (100*counts.loc[[2, 20, 21, 40, 41, 60, 61, 70, 71, 80, 81]]/counts.sum()).round(1)

cuadro = pd.concat([cuadro, counts_pct], axis = 1)
cuadro = cuadro.rename(columns = {'P0910':'Poblacion (%)'})
cuadro.index = ['No asistió', 'Primaria', 'P. completa', 'Secundaria','S. completa', 'Terciario', 'T. completo', 
             'Universidad', 'U. completa', 'Postgrado', 'P. completo']

cuadro = cuadro.round({'Ingresos (mediana)': -2, 'Pobreza (%)': 1, 'Indigencia (%)': 1, 'Poblacion (%)': 1})
cuadro.style.bar(subset = ['Poblacion (%)'], vmin = 0)
# Out:
# <style  type="text/css" >
#     #T_fc926010_3975_11eb_aaf2_5ce0c5892623row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.0%, transparent 8.0%);
#         }    #T_fc926010_3975_11eb_aaf2_5ce0c5892623row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.0%, transparent 48.0%);
#         }    #T_fc926010_3975_11eb_aaf2_5ce0c5892623row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_fc926010_3975_11eb_aaf2_5ce0c5892623row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 49.5%, transparent 49.5%);
#         }    #T_fc926010_3975_11eb_aaf2_5ce0c5892623row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 71.6%, transparent 71.6%);
#         }    #T_fc926010_3975_11eb_aaf2_5ce0c5892623row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.5%, transparent 10.5%);
#         }    #T_fc926010_3975_11eb_aaf2_5ce0c5892623row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.3%, transparent 23.3%);
#         }    #T_fc926010_3975_11eb_aaf2_5ce0c5892623row7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 21.5%, transparent 21.5%);
#         }    #T_fc926010_3975_11eb_aaf2_5ce0c5892623row8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.5%, transparent 25.5%);
#         }    #T_fc926010_3975_11eb_aaf2_5ce0c5892623row9_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 1.1%);
#         }    #T_fc926010_3975_11eb_aaf2_5ce0c5892623row10_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.5%, transparent 2.5%);
#         }</style><table id="T_fc926010_3975_11eb_aaf2_5ce0c5892623" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Ingresos (mediana)</th>        <th class="col_heading level0 col1" >Pobreza (%)</th>        <th class="col_heading level0 col2" >Indigencia (%)</th>        <th class="col_heading level0 col3" >Poblacion (%)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fc926010_3975_11eb_aaf2_5ce0c5892623level0_row0" class="row_heading level0 row0" >No asistió</th>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row0_col0" class="data row0 col0" >15000</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row0_col1" class="data row0 col1" >40.6</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row0_col2" class="data row0 col2" >13.2</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row0_col3" class="data row0 col3" >2.2</td>
#             </tr>
#             <tr>
#                         <th id="T_fc926010_3975_11eb_aaf2_5ce0c5892623level0_row1" class="row_heading level0 row1" >Primaria</th>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row1_col0" class="data row1 col0" >16100</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row1_col1" class="data row1 col1" >39.5</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row1_col2" class="data row1 col2" >13</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row1_col3" class="data row1 col3" >13.2</td>
#             </tr>
#             <tr>
#                         <th id="T_fc926010_3975_11eb_aaf2_5ce0c5892623level0_row2" class="row_heading level0 row2" >P. completa</th>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row2_col0" class="data row2 col0" >18900</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row2_col1" class="data row2 col1" >34.3</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row2_col2" class="data row2 col2" >9.7</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row2_col3" class="data row2 col3" >27.5</td>
#             </tr>
#             <tr>
#                         <th id="T_fc926010_3975_11eb_aaf2_5ce0c5892623level0_row3" class="row_heading level0 row3" >Secundaria</th>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row3_col0" class="data row3 col0" >23900</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row3_col1" class="data row3 col1" >32.3</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row3_col2" class="data row3 col2" >8.5</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row3_col3" class="data row3 col3" >13.6</td>
#             </tr>
#             <tr>
#                         <th id="T_fc926010_3975_11eb_aaf2_5ce0c5892623level0_row4" class="row_heading level0 row4" >S. completa</th>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row4_col0" class="data row4 col0" >31200</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row4_col1" class="data row4 col1" >20.5</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row4_col2" class="data row4 col2" >4.5</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row4_col3" class="data row4 col3" >19.7</td>
#             </tr>
#             <tr>
#                         <th id="T_fc926010_3975_11eb_aaf2_5ce0c5892623level0_row5" class="row_heading level0 row5" >Terciario</th>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row5_col0" class="data row5 col0" >32500</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row5_col1" class="data row5 col1" >18</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row5_col2" class="data row5 col2" >4.2</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row5_col3" class="data row5 col3" >2.9</td>
#             </tr>
#             <tr>
#                         <th id="T_fc926010_3975_11eb_aaf2_5ce0c5892623level0_row6" class="row_heading level0 row6" >T. completo</th>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row6_col0" class="data row6 col0" >40200</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row6_col1" class="data row6 col1" >9.4</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row6_col2" class="data row6 col2" >1.6</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row6_col3" class="data row6 col3" >6.4</td>
#             </tr>
#             <tr>
#                         <th id="T_fc926010_3975_11eb_aaf2_5ce0c5892623level0_row7" class="row_heading level0 row7" >Universidad</th>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row7_col0" class="data row7 col0" >37600</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row7_col1" class="data row7 col1" >11.3</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row7_col2" class="data row7 col2" >2.5</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row7_col3" class="data row7 col3" >5.9</td>
#             </tr>
#             <tr>
#                         <th id="T_fc926010_3975_11eb_aaf2_5ce0c5892623level0_row8" class="row_heading level0 row8" >U. completa</th>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row8_col0" class="data row8 col0" >57200</td>
#                         <td id="T_fc926010_3975_11eb_aaf2_5ce0c5892623row8_col1" class="data row8 col1" >4.6</td>

# %% [markdown]
# *Mayores de 24 años

# %% [markdown]
# ## Dependencia geografica
# ### Porcentaje de personas en pobreza por departamento.

# %%
pob_frac = data.loc[data.PROV.isin([2, 6, 2])].groupby(['IDFRAC','DPTO'])[['Pobreza']].mean().reset_index()
# pob_frac = data.loc[data.AGLOMERADO.isin([32])].groupby(['IDFRAC','DPTO'])[['Pobreza']].mean().reset_index()
# pob_frac = data.loc[data.PROV.isin([82])].groupby(['IDFRAC','DPTO'])[['Pobreza']].mean().reset_index()
# pob_frac = data.loc[data.AGLOMERADO.isin([25])].groupby(['IDFRAC','DPTO'])[['Pobreza']].mean().reset_index()

frac_gdf = gpd.read_file('./../../../../../../../home/miglesia/Documents/censo_geo/pxfracdatosok.shp', )

pob_gdf = gpd.GeoDataFrame(pob_frac.merge(frac_gdf), crs = {'init': 'epsg:4326'})
# frac_gdf['personas'] = pd.to_numeric(frac_gdf['personas'])

# Fill na with median. Esp for areas of little pop.
# # data.groupby('DPTO').count().iloc[:, 0].sort_values(ascending = False).head(10)
# pob_gdf.loc[pob_gdf.personas < 3000, 'Pobreza'] = np.nan
# pob_gdf = pob_gdf.fillna(pob_dpto_gdf.Pobreza.median())

gdf = pob_gdf#.plot(column = 'Pobreza')

fig, ax = plt.subplots(1, figsize = (25, 20))
dptos_gdf.loc[dptos_gdf.codpcia.isin(['02', '06'])].to_crs({'init': 'epsg:3395'}).translate(yoff = 220, xoff = 30).plot(color = 'None', edgecolor = '.4', lw = .4, ax = ax, zorder = 10)
dptos_gdf.loc[dptos_gdf.codpcia.isin(['02', '06'])].to_crs({'init': 'epsg:3395'}).translate(yoff = 0, xoff = 0).plot(color = 'None', edgecolor = 'w', lw = .4, ax = ax, zorder = 10)
gdf.fillna(0).to_crs({'init': 'epsg:3395'}).plot(column = 'Pobreza', ax = ax, vmin = 0, vmax = .6, cmap = 'RdYlGn_r', lw = 0)
plt.axis('off')
# x1, y1, x2, y2 = tuple(gdf.fillna(0).to_crs({'init': 'epsg:3395'}).total_bounds)
x1, y1, x2, y2 = (-6583053, -4171597, -6424188, -4005023)
plt.xlim(x1, x2)
plt.ylim(y1, y2)

ejido = gpd.read_file('./../../../../../../../home/miglesia/Documents/censo_geoejidos/ejido_BA', driver='GeoJSON')
ejido.loc[[1]].to_crs({'init': 'epsg:3395'}).plot(color = 'w', ax = ax)
ejido
plt.savefig("./mapa_portada.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-63-bb5720af586b> in <module>()
#      25 plt.ylim(y1, y2)
#      26
# ---> 27 ejido = gpd.read_file('./../../Documents/censo_geo/ejidos/ejido_BA', driver='GeoJSON')
#      28 ejido.loc[[1]].to_crs({'init': 'epsg:3395'}).plot(color = 'w', ax = ax)
#      29 ejido
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/geopandas/io/file.py in read_file(filename, bbox, **kwargs)
#      63         reader = fiona.open
#      64
# ---> 65     with reader(path_or_bytes, **kwargs) as features:
#      66         crs = features.crs
#      67         if bbox is not None:
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/fiona/__init__.py in open(path, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt)
#     160                 raise IOError("no such archive file: %r" % archive)
#     161         elif path != '-' and not os.path.exists(path):
# --> 162             raise IOError("no such file or directory: %r" % path)
#     163         c = Collection(path, mode, driver=driver, encoding=encoding,
#     164                        layer=layer, vsi=vsi, archive=archive,
#
# OSError: no such file or directory: './../../Documents/censo_geo/ejidos/ejido_BA'

# %%
import geopandas as gpd
dptos_gdf = gpd.read_file('./../../../../../../../home/miglesia/Documents/censo_geo/pxdptodatosok.shp')
dptos_gdf.crs = {'init': 'epsg:4326'} #latlong
# dptos_gdf = dptos_gdf.to_crs({'init': 'epsg:3395'}) #lo dejamos en metrico
dptos_gdf['personas'] = pd.to_numeric(dptos_gdf['personas'])
dptos_gdf = dptos_gdf.to_crs(fancy_crs)

data['link'] = data['DPTO'].astype(str).str.zfill(5)
pob_dpto = data.groupby('link')[['Pobreza']].mean().reset_index()

pob_dpto['link'] = pob_dpto.link.astype(float).astype(int).astype(str).str.zfill(5)
pob_dpto_gdf = gpd.GeoDataFrame(pob_dpto.merge(dptos_gdf), crs = fancy_crs)
# data.groupby('DPTO').count().iloc[:, 0].sort_values(ascending = False).head(10)

pob_dpto_gdf.loc[pob_dpto_gdf.personas < 1300, 'Pobreza'] = np.nan
pob_dpto_gdf = pob_dpto_gdf.fillna(pob_dpto_gdf.Pobreza.median())
gdf = pob_dpto_gdf#.plot(column = 'Pobreza')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn

fig, ax = plt.subplots(1, figsize = (12, 20))
gdf.fillna(0).plot(column = 'Pobreza', ax = ax, vmin = .1, vmax = .65, cmap = 'RdYlGn_r', lw = 0)

provs_gdf.translate(yoff = 2200, xoff = 300).plot(color = 'None', edgecolor = '.4', lw = .4, ax = ax, zorder = 10)
provs_gdf.translate().plot(color = 'None', edgecolor = 'w', lw = .4, ax = ax, zorder = 10)

# # Encuadre ARG
ax.set_xlim(-.75e6, 1.25e6)
ax.set_ylim(-2.3e6, 1.6e6)
# ax.set_xlim(-8300000, -5750000)
# ax.set_ylim(-7450000, -2400000)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Porcentaje de personas en pobreza por fraccion censal.
# #### Ejido Urbano AMBA

# %% [markdown]
# # Dependencia Temporal

# %%
# df = pd.read_csv('./../data/cuadro_AGLO_si_Q_pct', index_col=[0, 1], header = [0, 1]).unstack(0, 1)
# df.index = pd.DatetimeIndex(df.index, freq = 'Q')

# df_ = df[['Indigencia', 'Pobreza']].groupby(pd.Grouper(level = 0, freq = '6MS')).mean().T
# df_.index = pd.MultiIndex.from_tuples([(x[0], x[1], 'Aglomerados' if x[2] else 'Resto') for x in df_.index])
# show = df_.copy()
# show.columns = show.columns.to_period("6M")
# show

# %% [markdown]
# ### Porcentajes, 10 provincias. (2018)

# %%
cuadro2 = pd.read_csv('./../data/cuadro1_'+str(frac)+'_ARG', index_col=[0, 1], header = [0, 1, 2])
df = cuadro2.iloc[:, cuadro2.columns.get_level_values(0).isin(['Indigencia', 'Pobreza'])
            & cuadro2.columns.get_level_values(2).isin(['Hogares', 'Personas'])
                 & cuadro2.columns.get_level_values(1).isin(['mean'])]

# Leave just time as index
df = df.unstack()

df.index = pd.DatetimeIndex(df.index)

# Ultimo periodo
x = df.loc['2018'].mean().unstack([3, 1])
# x.columns = ['Fuera de aglomerados', 'Aglomerados']

# myround(x, 20).astype(int)
x.columns = x.columns.droplevel(1)
display(x.T.reindex(x.T.sum(1).sort_values(ascending = False).index).round(1))

# Rolling 4 trimestres de interpolado
df = df.resample('Q').mean().interpolate()
# Out:
#                                 Indigencia          Pobreza
#                                    Hogares Personas Hogares Personas
# NOMPROV
# Santiago del Estero                   12.8     16.1    39.2     48.6
# Formosa                               13.5     16.6    38.1     46.8
# Chaco                                 13.1     16.5    37.3     46.5
# Misiones                              11.8     15.3    35.3     45.0
# Corrientes                            11.9     15.5    34.5     44.6
# Salta                                 11.5     14.2    35.4     43.9
# San Juan                               9.3     11.1    34.1     40.8
# Tucuman                                9.6     11.2    32.1     39.3
# Jujuy                                  9.1     10.5    32.4     40.1
# Catamarca                              8.6     10.5    30.9     39.3
# La Rioja                               6.9      8.4    31.4     38.8
# Entre Rios                             7.2      9.8    26.4     35.4
# San Luis                               6.0      8.2    26.6     35.2
# Mendoza                                5.5      7.0    25.5     33.0
# Santa Fe                               6.1      8.3    22.0     30.0
# Cordoba                                5.1      6.7    21.8     29.6
# Buenos Aires                           5.2      6.8    21.6     28.4
# La Pampa                               5.3      7.5    19.1     27.0
# Neuquen                                5.3      6.5    19.9     25.0
# Chubut                                 4.6      5.8    18.8     25.0
# Santa Cruz                             3.0      3.7    17.4     22.8
# Tierra del Fuego                       2.6      2.0    10.7     12.0
# Ciudad Autonoma de Buenos Aires        2.5      2.8     8.5     11.6
# Rio Negro                              NaN      NaN     NaN      NaN

# %%
# # Niveles
# show = df.groupby(pd.TimeGrouper('Y', level = 0)).mean()
# show.columns = show.columns.droplevel(1)
# show.index = range(2007, 2019)

# %%
# diferencia
show = df.diff(4).groupby(pd.TimeGrouper('Y', level = 0)).mean()
show.columns = show.columns.droplevel(1)
show.columns = show.columns.swaplevel(0, 2).swaplevel(1,2)
show.index = range(startyr, endyr)

choice = np.random.choice(show.columns.get_level_values('NOMPROV').unique(), 10)

show.T.loc[choice].sort_index().round(1).style.applymap(color_negative_red)
# Out:
# <style  type="text/css" >
#     #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col0 {
#             color:  black;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col1 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col2 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col3 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col4 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col5 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col6 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col7 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col8 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col9 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col10 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col11 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col12 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col13 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col14 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col15 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col16 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row0_col17 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col0 {
#             color:  black;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col1 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col2 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col3 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col4 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col5 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col6 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col7 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col8 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col9 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col10 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col11 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col12 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col13 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col14 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col15 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col16 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row1_col17 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col0 {
#             color:  black;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col1 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col2 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col3 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col4 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col5 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col6 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col7 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col8 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col9 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col10 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col11 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col12 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col13 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col14 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col15 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col16 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row2_col17 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col0 {
#             color:  black;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col1 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col2 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col3 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col4 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col5 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col6 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col7 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col8 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col9 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col10 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col11 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col12 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col13 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col14 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col15 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col16 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row3_col17 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col0 {
#             color:  black;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col1 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col2 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col3 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col4 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col5 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col6 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col7 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col8 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col9 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col10 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col11 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col12 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col13 {
#             color:  red;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col14 {
#             color:  green;
#         }    #T_5f15411c_3976_11eb_aaf2_5ce0c5892623row4_col15 {

# %% [markdown]
# ## Niveles (%)
# ### Por Region y aglomerado. Promedio 2018.

# %%
cuadro = pd.read_csv('./../data/cuadro0_'+str(frac)+'_ARG', index_col=[0, 1, 2], header = [0, 1, 2])
df = cuadro.iloc[:, cuadro.columns.get_level_values(0).isin(['Indigencia', 'Pobreza'])
            & cuadro.columns.get_level_values(2).isin(['Hogares', 'Personas'])
                 & cuadro.columns.get_level_values(1).isin(['mean'])]

# Leave just time as index
df = df.unstack([1, 2]).dropna(1)
df.index = pd.DatetimeIndex(df.index)

# Ultimo periodo
x = df.loc['2018'].mean().unstack([3, 4, 1]).dropna(1)
# # x.columns = ['Fuera de aglomerados', 'Aglomerados']
# # myround(x, 20).astype(int)
x.columns = x.columns.droplevel(-1)
display(x.T.reindex(x.T.sum(1).sort_values(ascending = False).index).round(1))

# # Rolling 4 trimestres de interpolado
# df = df.resample('Q').mean().interpolate()
# Out:
#                                      Indigencia          Pobreza
#                                         Hogares Personas Hogares Personas
# Region            NOMAGLO
# Noroeste          Fuera de aglom.          13.7     16.8    42.0     51.5
# Noreste           Fuera de aglom.          14.3     18.5    40.2     50.6
#                   Formosa                  10.3     11.8    32.8     39.0
# Cuyo              Fuera de aglom.           8.2     10.5    33.0     41.1
# Noreste           Resistencia               9.1     11.2    29.0     36.5
# Noroeste          Sgo del Estero            7.9      9.4    29.9     37.3
# Noreste           Corrientes                9.1     11.6    27.4     36.1
# Cuyo              San Juan                  6.8      8.0    28.6     35.5
# Noreste           Posadas                   8.0     10.1    26.1     34.2
# Noroeste          Salta                     7.9      9.2    26.8     33.1
# Cuyo              La Rioja                  5.5      6.3    27.9     34.1
# Noroeste          Jujuy                     7.1      7.7    25.5     31.6
#                   Tucuman                   7.1      8.5    25.1     31.3
#                   Catamarca                 6.3      7.5    25.0     32.3
# Cuyo              San Luis                  5.1      7.1    24.5     32.8
# Pampeana          Santa Fe                  6.8      9.1    22.8     30.7
#                   Fuera de aglom.           5.7      7.8    22.3     30.6
# Gran Buenos Aires GBA                       5.6      7.0    23.1     29.6
# Pampeana          San Nicolas               4.4      5.8    22.8     30.9
# Cuyo              Mendoza                   4.5      5.7    21.9     29.2
# Patagónica        Fuera de aglom.           5.1      6.5    21.5     28.0
# Pampeana          Cordoba                   5.0      6.4    20.8     27.7
#                   Rosario                   5.2      6.8    19.5     26.3
#                   Parana                    4.5      5.8    20.0     26.1
#                   Santa Rosa                5.2      7.3    17.8     25.2
# Patagónica        Neuquen                   4.8      5.7    17.6     22.0
# Pampeana          La Plata                  4.3      5.7    16.4     22.9
# Patagónica        Rawson-Trelew             3.8      4.8    16.8     22.6
# Pampeana          Bahia Blanca              3.9      5.4    15.4     21.6
#                   Mar del Plata             3.8      5.0    15.8     21.5
# Patagónica        Cdro Rivadavia            3.7      4.6    16.0     21.0
#                   Rio Gallegos              2.2      2.5    14.3     18.7
#                   Ushuaia-Rio Grande        2.6      2.0    10.7     12.0
# Gran Buenos Aires CABA                      2.5      2.8     8.5     11.6

# %% [markdown]
# ## Cambio en niveles (%)
# ### Por aglomerado en regiones.

# %%
# diferencia
show = df.diff(4).groupby(pd.TimeGrouper('Y', level = 0)).mean()
show.columns = show.columns.droplevel(1)
show.columns = show.columns.swaplevel(0,2).swaplevel(1,3)
show.index = range(startyr, endyr)

# choice = np.random.choice(, 10)
show = show.T.sort_index().round()

for region in show.index.get_level_values('Region').unique():
    display(md('#### '+region))
    display(show.loc[region].style.applymap(color_negative_red))
# Out:
# #### Cuyo
# <style  type="text/css" >
#     #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col0 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col1 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col2 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col3 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col4 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col5 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col6 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col7 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col8 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col9 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col10 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col11 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col12 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col13 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col14 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col15 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col16 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row0_col17 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col0 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col1 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col2 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col3 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col4 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col5 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col6 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col7 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col8 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col9 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col10 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col11 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col12 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col13 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col14 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col15 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col16 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row1_col17 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col0 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col1 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col2 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col3 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col4 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col5 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col6 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col7 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col8 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col9 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col10 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col11 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col12 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col13 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col14 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col15 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col16 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row2_col17 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col0 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col1 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col2 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col3 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col4 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col5 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col6 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col7 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col8 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col9 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col10 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col11 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col12 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col13 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col14 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col15 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col16 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row3_col17 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col0 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col1 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col2 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col3 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col4 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col5 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col6 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col7 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col8 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col9 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col10 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col11 {
#             color:  red;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col12 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col13 {
#             color:  black;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col14 {
#             color:  green;
#         }    #T_651b3968_3976_11eb_aaf2_5ce0c5892623row4_col15
# #### Gran Buenos Aires
# <style  type="text/css" >
#     #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col0 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col1 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col2 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col3 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col4 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col5 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col6 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col7 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col8 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col9 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col10 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col11 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col12 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col13 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col14 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col15 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col16 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row0_col17 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col0 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col1 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col2 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col3 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col4 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col5 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col6 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col7 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col8 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col9 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col10 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col11 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col12 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col13 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col14 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col15 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col16 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row1_col17 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col0 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col1 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col2 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col3 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col4 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col5 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col6 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col7 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col8 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col9 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col10 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col11 {
#             color:  red;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col12 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col13 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col14 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col15 {
#             color:  red;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col16 {
#             color:  red;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row2_col17 {
#             color:  red;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col0 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col1 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col2 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col3 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col4 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col5 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col6 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col7 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col8 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col9 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col10 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col11 {
#             color:  red;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col12 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col13 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col14 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col15 {
#             color:  red;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col16 {
#             color:  red;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row3_col17 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row4_col0 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row4_col1 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row4_col2 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row4_col3 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row4_col4 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row4_col5 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row4_col6 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row4_col7 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row4_col8 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row4_col9 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row4_col10 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row4_col11 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row4_col12 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row4_col13 {
#             color:  black;
#         }    #T_6580df02_3976_11eb_aaf2_5ce0c5892623row4_col14 {
#             color:  green;
#         }    #T_6580df02_3976_11eb_aaf2_5ce
# #### Noreste
# <style  type="text/css" >
#     #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col0 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col1 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col2 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col3 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col4 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col5 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col6 {
#             color:  red;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col7 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col8 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col9 {
#             color:  red;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col10 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col11 {
#             color:  red;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col12 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col13 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col14 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col15 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col16 {
#             color:  red;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row0_col17 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col0 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col1 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col2 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col3 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col4 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col5 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col6 {
#             color:  red;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col7 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col8 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col9 {
#             color:  red;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col10 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col11 {
#             color:  red;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col12 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col13 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col14 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col15 {
#             color:  red;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col16 {
#             color:  red;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row1_col17 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col0 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col1 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col2 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col3 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col4 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col5 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col6 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col7 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col8 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col9 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col10 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col11 {
#             color:  red;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col12 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col13 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col14 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col15 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col16 {
#             color:  red;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row2_col17 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col0 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col1 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col2 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col3 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col4 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col5 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col6 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col7 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col8 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col9 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col10 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col11 {
#             color:  red;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col12 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col13 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col14 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col15 {
#             color:  red;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col16 {
#             color:  red;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row3_col17 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_col0 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_col1 {
#             color:  red;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_col2 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_col3 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_col4 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_col5 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_col6 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_col7 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_col8 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_col9 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_col10 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_col11 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_col12 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_col13 {
#             color:  black;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_col14 {
#             color:  green;
#         }    #T_6655139e_3976_11eb_aaf2_5ce0c5892623row4_co
# #### Noroeste
# <style  type="text/css" >
#     #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col0 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col1 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col2 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col3 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col4 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col5 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col6 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col7 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col8 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col9 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col10 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col11 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col12 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col13 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col14 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col15 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col16 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row0_col17 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col0 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col1 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col2 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col3 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col4 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col5 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col6 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col7 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col8 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col9 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col10 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col11 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col12 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col13 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col14 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col15 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col16 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row1_col17 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col0 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col1 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col2 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col3 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col4 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col5 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col6 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col7 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col8 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col9 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col10 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col11 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col12 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col13 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col14 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col15 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col16 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row2_col17 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col0 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col1 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col2 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col3 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col4 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col5 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col6 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col7 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col8 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col9 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col10 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col11 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col12 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col13 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col14 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col15 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col16 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row3_col17 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col0 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col1 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col2 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col3 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col4 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col5 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col6 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col7 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col8 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col9 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col10 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col11 {
#             color:  red;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col12 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col13 {
#             color:  green;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col14 {
#             color:  black;
#         }    #T_67560c44_3976_11eb_aaf2_5ce0c5892623row4_col1
# #### Pampeana
# <style  type="text/css" >
#     #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col0 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col1 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col2 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col3 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col4 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col5 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col6 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col7 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col8 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col9 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col10 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col11 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col12 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col13 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col14 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col15 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col16 {
#             color:  red;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row0_col17 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col0 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col1 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col2 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col3 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col4 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col5 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col6 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col7 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col8 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col9 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col10 {
#             color:  red;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col11 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col12 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col13 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col14 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col15 {
#             color:  red;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col16 {
#             color:  red;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row1_col17 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col0 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col1 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col2 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col3 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col4 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col5 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col6 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col7 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col8 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col9 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col10 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col11 {
#             color:  red;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col12 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col13 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col14 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col15 {
#             color:  red;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col16 {
#             color:  red;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row2_col17 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col0 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col1 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col2 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col3 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col4 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col5 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col6 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col7 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col8 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col9 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col10 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col11 {
#             color:  red;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col12 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col13 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col14 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col15 {
#             color:  red;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col16 {
#             color:  red;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row3_col17 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row4_col0 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row4_col1 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row4_col2 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row4_col3 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row4_col4 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row4_col5 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row4_col6 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row4_col7 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row4_col8 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row4_col9 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row4_col10 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row4_col11 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row4_col12 {
#             color:  black;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row4_col13 {
#             color:  red;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c5892623row4_col14 {
#             color:  green;
#         }    #T_69125718_3976_11eb_aaf2_5ce0c589262
# #### Patagónica
# <style  type="text/css" >
#     #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col0 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col1 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col2 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col3 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col4 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col5 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col6 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col7 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col8 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col9 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col10 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col11 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col12 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col13 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col14 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col15 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col16 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row0_col17 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col0 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col1 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col2 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col3 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col4 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col5 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col6 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col7 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col8 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col9 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col10 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col11 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col12 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col13 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col14 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col15 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col16 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row1_col17 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col0 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col1 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col2 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col3 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col4 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col5 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col6 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col7 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col8 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col9 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col10 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col11 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col12 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col13 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col14 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col15 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col16 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row2_col17 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col0 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col1 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col2 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col3 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col4 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col5 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col6 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col7 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col8 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col9 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col10 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col11 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col12 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col13 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col14 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col15 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col16 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row3_col17 {
#             color:  red;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col0 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col1 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col2 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col3 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col4 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col5 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col6 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col7 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col8 {
#             color:  green;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col9 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col10 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col11 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col12 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col13 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col14 {
#             color:  black;
#         }    #T_6a4bd686_3976_11eb_aaf2_5ce0c5892623row4_col1

# %% [markdown]
# ## Niveles (%)
# ### Partidos y Comunas del AMBA (muestreo)

# %%
fig, ax = plt.subplots(1, figsize = (8, 8))
gdf.fillna(0).plot(column = 'Pobreza', ax = ax, vmin = .1, vmax = .65, cmap = 'RdYlGn_r',
                                                 edgecolor = '.4', lw = 0)
#Partidos b&n
gdf.to_crs({'init': 'epsg:3395'}).fillna(0).plot(column = 'Pobreza', ax = ax, vmin = .1, vmax = .65, cmap = 'RdYlGn_r',
                                                 edgecolor = '.4', lw = 0)
dptos_gdf.to_crs({'init': 'epsg:3395'}).loc[dptos_gdf.to_crs({'init': 'epsg:3395'}).codpcia.isin(['02', '06'])].translate(yoff = 220, xoff = 30).plot(color = 'None', edgecolor = '.4', lw = .4, ax = ax, zorder = 10)
dptos_gdf.to_crs({'init': 'epsg:3395'}).loc[dptos_gdf.to_crs({'init': 'epsg:3395'}).codpcia.isin(['02', '06'])].translate(yoff = 0, xoff = 0).plot(color = 'None', edgecolor = 'w', lw = .4, ax = ax, zorder = 10)

plt.xlim(-6570000, -6450000)
plt.ylim(-4150000, -4020000)
# ax.set_xlim(530e5, 7e5)
# ax.set_ylim(-25000, 75000)
plt.axis('off')

plt.show()


cuadro = pd.read_csv('./../data/cuadro5_'+str(frac)+'_AMBA', index_col=[0, 1], header = [0, 1, 2])
df = cuadro.iloc[:, cuadro.columns.get_level_values(0).isin(['Indigencia', 'Pobreza'])
            & cuadro.columns.get_level_values(2).isin(['Hogares', 'Personas'])
                 & cuadro.columns.get_level_values(1).isin(['mean'])]

# Dptos de codigo a nombres...
dptos = pd.read_csv('./../data/radio_ref.csv')[['DPTO','NOMDPTO']].drop_duplicates().set_index('DPTO')
nomdptos = dptos.to_dict()['NOMDPTO']
df.index = pd.MultiIndex.from_tuples([(x[0], nomdptos[x[1]]) for x in df.index])

# Leave just time as index
df = df.unstack()

df.index = pd.DatetimeIndex(df.index)

# Ultimo periodo
x = df.loc['2018'].mean().unstack([3, 1])
# x.columns = ['Fuera de aglomerados', 'Aglomerados']

# myround(x, 20).astype(int)
x.columns = x.columns.droplevel(1)
display(x.T.reindex(x.T.sum(1).sort_values(ascending = False).index).round(1))

# Rolling 4 trimestres de interpolado
df = df.resample('Q').mean().interpolate()
# Out:
#                     Indigencia          Pobreza
#                        Hogares Personas Hogares Personas
# Florencio Varela          10.0     12.2    36.2     43.6
# José C. Paz                8.5     10.0    32.9     39.8
# Moreno                     8.4     10.4    32.2     39.5
# Ezeiza                     7.3      9.1    30.7     37.5
# Merlo                      7.2      8.6    29.2     36.2
# Malvinas Argentinas        6.8      8.1    27.5     33.2
# Esteban Echeverría         6.7      8.1    26.4     32.6
# La Matanza                 6.3      7.7    26.5     32.7
# Almirante Brown            5.7      7.3    25.3     32.2
# Comuna 08                  6.6      7.6    23.6     30.3
# Berazategui                5.6      7.1    24.0     30.9
# Ensenada                   5.7      8.0    21.9     32.0
# San Miguel                 6.0      7.1    24.0     30.0
# Quilmes                    5.4      7.2    22.3     30.2
# Tigre                      5.6      6.7    23.7     28.8
# Lomas de Zamora            5.6      6.5    22.8     28.0
# Berisso                    4.4      5.7    20.2     27.4
# San Fernando               5.0      6.1    18.4     24.2
# General San Martín         3.8      4.7    17.2     23.2
# Hurlingham                 3.6      4.3    17.5     22.7
# Avellaneda                 4.1      5.0    16.4     22.3
# La Plata                   4.2      5.4    15.5     21.4
# Lanús                      3.4      4.2    16.6     21.7
# Comuna 04                  3.6      4.4    15.4     20.7
# Tres de Febrero            3.1      4.0    13.3     17.9
# Ituzaingó                  2.7      2.9    14.4     17.3
# Morón                      2.6      3.7    12.4     17.0
# Comuna 01                  3.9      4.2    11.8     15.6
# Comuna 07                  3.1      3.9    11.3     16.0
# Comuna 09                  2.6      3.3    10.8     14.3
# San Isidro                 2.0      2.3    10.6     14.2
# Comuna 03                  2.6      2.6     7.6     10.0
# Comuna 10                  2.0      2.1     7.7      9.3
# Comuna 15                  1.9      1.9     6.5      8.7
# Vicente López              1.4      1.4     7.1      8.6
# Comuna 02                  3.0      2.7     6.2      6.5
# Comuna 14                  2.6      2.1     5.6      6.3
# Comuna 06                  2.0      2.0     5.5      6.7
# Comuna 12                  1.1      1.1     5.7      7.3
# Comuna 11                  0.9      0.8     5.6      7.6
# Comuna 05                  1.3      1.6     4.8      6.9
# Comuna 13                  1.2      1.1     4.1      5.0
# Escobar                    NaN      NaN     NaN      NaN
# San Vicente                NaN      NaN     NaN      NaN
# General Rodríguez          NaN      NaN     NaN      NaN
# Marcos Paz                 NaN      NaN     NaN      NaN
# Presidente Perón           NaN      NaN     NaN      NaN
# Pilar                      NaN      NaN     NaN      NaN

# %% [markdown]
# ## Cambio en niveles (%)

# %%
# diferencia
show = df.diff(4).groupby(pd.TimeGrouper('Y', level = 0)).mean()
show.columns = show.columns.droplevel(1)
show.columns = show.columns.swaplevel(0, 2).swaplevel(1,2)
show.index = range(startyr, endyr)

choice = np.random.choice(show.columns.get_level_values(0).unique(), 10)

show.T.loc[choice].sort_index().round(1).style.applymap(color_negative_red)
# Out:
# <style  type="text/css" >
#     #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col0 {
#             color:  black;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col1 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col2 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col3 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col4 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col5 {
#             color:  black;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col6 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col7 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col8 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col9 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col10 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col11 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col12 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col13 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col14 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col15 {
#             color:  black;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col16 {
#             color:  black;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row0_col17 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col0 {
#             color:  black;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col1 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col2 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col3 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col4 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col5 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col6 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col7 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col8 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col9 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col10 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col11 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col12 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col13 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col14 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col15 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col16 {
#             color:  black;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row1_col17 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col0 {
#             color:  black;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col1 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col2 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col3 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col4 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col5 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col6 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col7 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col8 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col9 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col10 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col11 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col12 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col13 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col14 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col15 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col16 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row2_col17 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col0 {
#             color:  black;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col1 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col2 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col3 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col4 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col5 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col6 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col7 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col8 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col9 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col10 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col11 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col12 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col13 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col14 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col15 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col16 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row3_col17 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col0 {
#             color:  black;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col1 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col2 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col3 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col4 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col5 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col6 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col7 {
#             color:  black;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col8 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col9 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col10 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col11 {
#             color:  black;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col12 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col13 {
#             color:  red;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col14 {
#             color:  green;
#         }    #T_73999ff2_3976_11eb_aaf2_5ce0c5892623row4_col15 {
#             color:

# %% [markdown]
# ## Lista de Aglomerados
# Y su poblacion (miles)

# %%
## Appendix
data = pd.read_csv('./../data/pobreza'+str(frac)+'.csv', usecols = ['DPTO', 'PERSONA_REF_ID', 'AGLOMERADO'])

aglo_labels = pd.read_csv('./../data/aglo_labels.csv')[['AGLOMERADO', 'NOMAGLO']]
radio_ref = pd.read_csv('./../data/radio_ref.csv').merge(aglo_labels)
data = data.merge(radio_ref[['DPTO','NOMAGLO', 'NOMPROV', 'NOMDPTO']].drop_duplicates())

pd.options.display.max_rows = 999
poblacion_por_aglo_dpto = data.loc[data.AGLOMERADO != 0].groupby(['NOMAGLO', 'NOMPROV', 'NOMDPTO'])[['PERSONA_REF_ID']].count().sort_index()/frac/yrs_pob_data/1e3
poblacion_por_aglo_dpto.columns = ['Poblacion (miles)']
poblacion_por_aglo_dpto.drop('Fuera de aglom.').round().style.bar(vmin = 0)

# poblacion (miles)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-568a07530aab> in <module>()
#       1 ## Appendix
# ----> 2 data = pd.read_csv('./../data/pobreza'+str(frac)+'.csv', usecols = ['DPTO', 'PERSONA_REF_ID', 'AGLOMERADO'])
#       3
#       4 aglo_labels = pd.read_csv('./../data/aglo_labels.csv')[['AGLOMERADO', 'NOMAGLO']]
#       5 radio_ref = pd.read_csv('./../data/radio_ref.csv').merge(aglo_labels)
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1893             if (self.usecols_dtype == 'string' and
#    1894                     not set(usecols).issubset(self.orig_names)):
# -> 1895                 _validate_usecols_names(usecols, self.orig_names)
#    1896
#    1897             if len(self.names) > len(usecols):
#
# ~/anaconda2/envs/my_pymc_env/lib/python3.6/site-packages/pandas/io/parsers.py in _validate_usecols_names(usecols, names)
#    1235         raise ValueError(
#    1236             "Usecols do not match columns, "
# -> 1237             "columns expected but not found: {missing}".format(missing=missing)
#    1238         )
#    1239
#
# ValueError: Usecols do not match columns, columns expected but not found: ['PERSONA_REF_ID']
