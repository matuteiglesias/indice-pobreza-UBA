# %%
import pandas as pd
pd.options.display.max_rows = 200

from IPython.display import HTML
HTML("<style>.container { width:100% !important; }</style>")
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Valores 2010 para variables seleccionadas.

# %%
frac = 0.01

# %%
df_list = []

for Q in ['2010-02-15', '2010-02-15', '2010-02-15', '2010-02-15']:
    df_ = pd.read_csv('./../data/Pobreza/pobreza_'+str(frac)+'_q'+Q+'.csv')
    
    df_list += [df_]
    
df = pd.concat(df_list)

# %%
len(df)/frac/4
# Out:
# 40005400.0

# %%
df['CONDACT'] = df['CONDACT'].map({0: 'Menor de 14', 1: 'Ocup', 2: 'Desoc', 3: 'Inac'})
df['CAT_OCUP'] = df['CAT_OCUP'].map({0: 'n.a.', 1: 'Patron', 2: 'C. Propia', 3: 'Empleado', 4: 'Familiar'})
df['CAT_INAC'] = df['CAT_INAC'].map({0: 'n.a.', 1: 'Jubil', 2: 'Renta', 3: 'Estud', 4: 'Ama Casa', 5: 'Menor de 6', 6: 'Discap', 7: 'Otros'})

# %%
df.columns
# Out:
# Index(['index', 'RADIO_REF_ID', 'URP', 'DPTO', 'HOGAR_REF_ID', 'H15', 'H16',
#        'PERSONA_REF_ID', 'P02', 'P03', 'P09', 'P10', 'CONDACT', 'IX_TOT',
#        'CAT_OCUP', 'CAT_INAC', 'P47T_persona', 'ANO4', 'Q', 'P0910',
#        'Grupo_Etario_3', 'Grupo_Etario_INDEC', 'Grupo_Etario_q10',
#        'P47T_hogar', 'CBA', 'CBT', 'CB_EQUIV', 'Pobreza', 'Indigencia',
#        'Pobreza_5usd', 'gap_pobreza', 'gap_indigencia', 'IDFRAC', 'PROV',
#        'NOMPROV', 'AGLOMERADO', 'Region'],
#       dtype='object')

# %%
tabla = df.groupby(['CONDACT', 'CAT_OCUP', 'CAT_INAC']).size().unstack([-2, -1]).sort_index(axis = 1)/4/frac
show = (tabla/1e6).round(2).fillna(0).replace(0, '')
show.to_excel('./personas_pob_total_CONDACT-CAT_OCUP-CAT_INAC.xlsx')
show
# Out:
# CAT_OCUP    C. Propia Empleado Familiar Patron     n.a.                     \
# CAT_INAC         n.a.     n.a.     n.a.   n.a. Ama Casa Discap Estud Jubil
# CONDACT
# Desoc            0.06     1.32
# Inac                                               3.06   0.03  2.98  3.89
# Menor de 14               0.04                                  5.39
# Ocup             1.02    17.37     0.01   0.07
#
# CAT_OCUP
# CAT_INAC    Menor de 6 Otros Renta  n.a.
# CONDACT
# Desoc                               0.05
# Inac                    0.44
# Menor de 14       3.99  0.07        0.21
# Ocup                                0.01

# %%
# tabla.sum().reset_index().astype(int)

# %%
tabla = df.groupby(['NOMPROV', 'CONDACT', 'CAT_OCUP', 'CAT_INAC']).size().unstack([-2, -1]).sort_index(axis = 1)/4/frac

# %%
show = (tabla/1e3).round(1).fillna(0).replace(0, '')
show.to_excel('./personas_pob_total_NOMPROV-CONDACT-CAT_OCUP-CAT_INAC.xlsx')
show
# Out:
# CAT_OCUP                                    C. Propia Empleado Familiar  \
# CAT_INAC                                         n.a.     n.a.     n.a.
# NOMPROV                         CONDACT
# Buenos Aires                    Desoc            26.3    543.0
#                                 Inac
#                                 Menor de 14               11.3
#                                 Ocup            412.5   7090.0      2.5
# Catamarca                       Desoc             0.4     12.4
#                                 Inac
#                                 Menor de 14                2.1
#                                 Ocup              9.2    145.4      0.3
# Chaco                           Desoc             1.6     25.0
#                                 Inac
#                                 Menor de 14                0.5
#                                 Ocup             31.0    376.5      0.8
# Chubut                          Desoc             0.7     16.8
#                                 Inac
#                                 Menor de 14                3.2
#                                 Ocup             10.8    233.4
# Ciudad Autónoma de Buenos Aires Desoc             3.4     89.6
#                                 Inac
#                                 Menor de 14                3.1
#                                 Ocup             73.5   1555.5      0.1
# Corrientes                      Desoc             0.8     24.8
#                                 Inac
#                                 Menor de 14                0.1
#                                 Ocup             24.4    356.4      0.5
# Córdoba                         Desoc             5.8    102.5
#                                 Inac
#                                 Menor de 14                3.1
#                                 Ocup             85.8   1445.3      0.4
# Entre Ríos                      Desoc             0.9     30.1
#                                 Inac
#                                 Menor de 14                0.4
#                                 Ocup             33.8    506.4      0.2
# Formosa                         Desoc             0.4     12.1
#                                 Inac
#                                 Menor de 14                0.2
#                                 Ocup             15.4    182.2      0.4
# Jujuy                           Desoc             0.6     22.0
#                                 Inac
#                                 Menor de 14                0.2
#                                 Ocup             14.6    263.2      0.3
# La Pampa                        Desoc             0.4      9.4
#                                 Inac
#                                 Menor de 14                0.2
#                                 Ocup             10.5    138.0
# La Rioja                        Desoc             0.4     12.7
#                                 Inac
#                                 Menor de 14                0.1
#                                 Ocup              5.0    143.3
# Mendoza                         Desoc             2.8     68.5
#                                 Inac
#                                 Menor de 14                1.7
#                                 Ocup             40.2    714.0      0.9
# Misiones                        Desoc             0.7     24.6
#                                 Inac
#                                 Menor de 14                0.4
#                                 Ocup             28.2    386.1      1.1
# Neuquén                         Desoc             0.4     19.8
#                                 Inac
#                                 Menor de 14                5.6
#                                 Ocup             10.2    236.0
# Río Negro                       Desoc             1.2     24.9
#                                 Inac
#                                 Menor de 14       0.2      1.8
#                                 Ocup             13.3    282.6      0.1
# Salta                           Desoc             0.9     36.1
#                                 Inac
#                                 Menor de 14                0.9
#                                 Ocup             25.8    449.1      0.7
# San Juan                        Desoc             0.8     22.7
#                                 Inac
#                                 Menor de 14                0.3
#                                 Ocup             15.9    258.3      0.2
# San Luis                        Desoc             1.0     16.4
#                                 Inac
#                                 Menor de 14                0.3
#                                 Ocup             10.4    179.4      0.3
# Santa Cruz                      Desoc             0.1     10.2
#                                 Inac
#                                 Menor de 14                0.7
#                                 Ocup              4.6    126.2
# Santa Fe                        Desoc             3.9    107.7
#                                 Inac
#                                 Menor de 14                2.0
#                                 Ocup             94.4   1400.1      0.1
# Santiago del Estero             Desoc             1.1     23.2
#                                 Inac
#                                 Menor de 14       0.1      0.1
#                                 Ocup             21.1    296.9      0.3
# Tierra del Fuego                Desoc             0.1      5.6
#                                 Inac
#                                 Menor de 14                0.2
#                                 Ocup              1.2     62.3
# Tucumán                         Desoc             1.9     55.3
#                                 Inac
#                                 Menor de 14       0.1      1.1
#                                 Ocup             28.7    540.4      1.3
#
# CAT_OCUP                                    Patron     n.a.                 \
# CAT_INAC                                      n.a. Ama Casa Discap   Estud
# NOMPROV                         CONDACT
# Buenos Aires                    Desoc          0.2
#                                 Inac                 1103.9   10.9  1054.6
#                                 Menor de 14                    0.7  2022.5
#                                 Ocup          30.2
# Catamarca                       Desoc
#                                 Inac                   26.6    0.2    35.7
#                                 Menor de 14                           60.6
#                                 Ocup           0.2
# Chaco                           Desoc
#                                 Inac                  109.3    1.0    94.2
#                                 Menor de 14                    0.3   182.7
#                                 Ocup           0.9                     0.1
# Chubut                          Desoc
#                                 Inac                   35.2    0.3    36.9
#                                 Menor de 14                           67.3
#                                 Ocup           0.5
# Ciudad Autónoma de Buenos Aires Desoc
#                                 Inac                  121.1    0.7   171.2
#                                 Menor de 14                    0.1   245.8
#                                 Ocup           8.4
# Corrientes                      Desoc
#                                 Inac                  102.6    1.2    87.4
#                                 Menor de 14                    0.4   152.3
#                                 Ocup           1.8
# Córdoba                         Desoc          0.1
#                                 Inac                  241.0    3.0   247.9
#                                 Menor de 14             0.1          420.4
#                                 Ocup           5.0
# Entre Ríos                      Desoc
#                                 Inac                  106.8    1.0    89.9
#                                 Menor de 14                          181.2
#                                 Ocup           1.6
# Formosa                         Desoc          0.1
#                                 Inac                   55.5    0.6    51.7
#                                 Menor de 14                           98.6
#                                 Ocup           0.1
# Jujuy                           Desoc
#                                 Inac                   53.7    0.7    68.1
#                                 Menor de 14                    0.1   104.0
#                                 Ocup           0.9
# La Pampa                        Desoc
#                                 Inac                   18.1    0.2    23.5
#                                 Menor de 14                           46.0
#                                 Ocup           0.5
# La Rioja                        Desoc
#                                 Inac                   23.9    0.2    34.1
#                                 Menor de 14                           46.5
#                                 Ocup           0.1
# Mendoza                         Desoc
#                                 Inac                  142.9    2.0   150.5
#                                 Menor de 14                    0.3   222.7
#                                 Ocup           3.2
# Misiones                        Desoc
#                                 Inac                  122.7    2.0    86.8
#                                 Menor de 14                    0.2   193.0
#                                 Ocup           1.6                     0.1
# Neuquén                         Desoc
#                                 Inac                   41.3    0.4    47.5
#                                 Menor de 14                           77.8
#                                 Ocup           0.9
# Río Negro                       Desoc
#                                 Inac                   46.0    1.4    47.6
#                                 Menor de 14                           87.7
#                                 Ocup           1.0
# Salta                           Desoc
#                                 Inac                  110.5    1.3   113.4
#                                 Menor de 14                    0.1   209.3
#                                 Ocup           1.2
# San Juan                        Desoc          0.1
#                                 Inac                   69.0    0.6    57.0
#                                 Menor de 14                           98.8
#                                 Ocup           0.8
# San Luis                        Desoc
#                                 Inac                   30.5    0.7    35.6
#                                 Menor de 14                    0.1    63.4
#                                 Ocup           0.7
# Santa Cruz                      Desoc
#                                 Inac                   16.7    0.1    24.6
#                                 Menor de 14                           43.0
#                                 Ocup           0.3
# Santa Fe                        Desoc
#                                 Inac                  241.2    2.6   222.9
#                                 Menor de 14                    0.1   387.0
#                                 Ocup           4.7
# Santiago del Estero             Desoc
#                                 Inac                   97.7    1.0    66.1
#                                 Menor de 14                    0.3   145.7
#                                 Ocup           0.7
# Tierra del Fuego                Desoc
#                                 Inac                    5.0            9.5
#                                 Menor de 14                           17.7
#                                 Ocup
# Tucumán                         Desoc
#                                 Inac                  134.4    0.8   122.8
#                                 Menor de 14                    0.2   217.6
#                                 Ocup           1.1
#
# CAT_OCUP                                                                     \
# CAT_INAC                                      Jubil Menor de 6  Otros Renta
# NOMPROV                         CONDACT
# Buenos Aires                    Desoc
#                                 Inac         1511.4             119.0   1.1
#                                 Menor de 14     0.1     1547.5   22.8
#                                 Ocup
# Catamarca                       Desoc
#                                 Inac           28.7               5.9   0.1
#                                 Menor de 14               36.6    0.7
#                                 Ocup
# Chaco                           Desoc
#                                 Inac           82.7              21.7   0.1
#                                 Menor de 14              113.3    3.3
#                                 Ocup
# Chubut                          Desoc
#                                 Inac           37.0               3.9
#                                 Menor de 14               54.2    0.2
#                                 Ocup
# Ciudad Autónoma de Buenos Aires Desoc
#                                 Inac          361.7              14.7   0.2
#                                 Menor de 14              197.8    2.3
#                                 Ocup
# Corrientes                      Desoc
#                                 Inac           95.3              20.4   0.1
#                                 Menor de 14              109.1    2.0
#                                 Ocup
# Córdoba                         Desoc
#                                 Inac          360.2              29.3   0.1
#                                 Menor de 14              308.6    5.8
#                                 Ocup
# Entre Ríos                      Desoc
#                                 Inac          134.3              16.4
#                                 Menor de 14              126.8    2.6
#                                 Ocup
# Formosa                         Desoc
#                                 Inac           40.9              13.1
#                                 Menor de 14               62.1    0.9
#                                 Ocup
# Jujuy                           Desoc
#                                 Inac           49.9              12.1   0.1
#                                 Menor de 14               73.2    1.0
#                                 Ocup
# La Pampa                        Desoc
#                                 Inac           33.8               2.1
#                                 Menor de 14               34.0    0.5
#                                 Ocup
# La Rioja                        Desoc
#                                 Inac           23.4               5.5
#                                 Menor de 14               38.3    0.3
#                                 Ocup
# Mendoza                         Desoc
#                                 Inac          175.7              18.2   0.1
#                                 Menor de 14              180.3    1.8
#                                 Ocup
# Misiones                        Desoc
#                                 Inac           88.1              19.2   0.1
#                                 Menor de 14              142.1    4.3
#                                 Ocup
# Neuquén                         Desoc
#                                 Inac           34.4               6.1
#                                 Menor de 14               59.9    1.2
#                                 Ocup
# Río Negro                       Desoc
#                                 Inac           46.9               5.1
#                                 Menor de 14               64.5    0.7
#                                 Ocup
# Salta                           Desoc
#                                 Inac           96.9              20.9
#                                 Menor de 14              139.0    2.9
#                                 Ocup
# San Juan                        Desoc
#                                 Inac           61.3               9.1   0.1
#                                 Menor de 14               79.1    1.8
#                                 Ocup
# San Luis                        Desoc
#                                 Inac           38.3               5.7   0.1
#                                 Menor de 14               44.4    0.3
#                                 Ocup
# Santa Cruz                      Desoc
#                                 Inac           14.5               1.8
#                                 Menor de 14               32.9    0.1
#                                 Ocup
# Santa Fe                        Desoc
#                                 Inac          352.1              36.6   0.1
#                                 Menor de 14              282.8    5.4
#                                 Ocup
# Santiago del Estero             Desoc
#                                 Inac           79.5              24.4
#                                 Menor de 14     0.1       96.7    3.3
#                                 Ocup
# Tierra del Fuego                Desoc
#                                 Inac            4.1               0.5
#                                 Menor de 14               12.2
#                                 Ocup
# Tucumán                         Desoc
#                                 Inac          141.5              27.4   0.1
#                                 Menor de 14     0.1      154.6    3.0
#                                 Ocup
#
# CAT_OCUP
# CAT_INAC                                     n.a.
# NOMPROV                         CONDACT
# Buenos Aires                    Desoc        21.3
#                                 Inac
#                                 Menor de 14  79.7
#                                 Ocup          4.8
# Catamarca                       Desoc         0.7
#                                 Inac
#                                 Menor de 14   6.9
#                                 Ocup          0.2
# Chaco                           Desoc         0.9
#                                 Inac
#                                 Menor de 14   2.6
#                                 Ocup          0.4
# Chubut                          Desoc         0.6
#                                 Inac
#                                 Menor de 14   3.6
#                                 Ocup          0.1
# Ciudad Autónoma de Buenos Aires Desoc         2.6
#                                 Inac
#                                 Menor de 14  17.0
#                                 Ocup          0.1
# Corrientes                      Desoc         1.1
#                                 Inac
#                                 Menor de 14   0.6
#                                 Ocup          0.5
# Córdoba                         Desoc         3.3
#                                 Inac
#                                 Menor de 14  16.9
#                                 Ocup          0.9
# Entre Ríos                      Desoc         0.9
#                                 Inac
#                                 Menor de 14   2.3
#                                 Ocup          0.1
# Formosa                         Desoc         0.3
#                                 Inac
#                                 Menor de 14   0.1
#                                 Ocup          0.2
# Jujuy                           Desoc         0.3
#                                 Inac
#                                 Menor de 14   3.7
#                                 Ocup          0.6
# La Pampa                        Desoc         0.8
#                                 Inac
#                                 Menor de 14   0.3
#                                 Ocup          0.1
# La Rioja                        Desoc         0.4
#                                 Inac
#                                 Menor de 14   3.8
#                                 Ocup
# Mendoza                         Desoc         2.2
#                                 Inac
#                                 Menor de 14  16.2
#                                 Ocup          0.2
# Misiones                        Desoc         0.9
#                                 Inac
#                                 Menor de 14   3.4
#                                 Ocup          0.8
# Neuquén                         Desoc         0.9
#                                 Inac
#                                 Menor de 14   7.0
#                                 Ocup
# Río Negro                       Desoc         1.4
#                                 Inac
#                                 Menor de 14   3.9
#                                 Ocup          0.3
# Salta                           Desoc         0.6
#                                 Inac
#                                 Menor de 14   5.7
#                                 Ocup          0.3
# San Juan                        Desoc         1.3
#                                 Inac
#                                 Menor de 14   3.8
#                                 Ocup          0.1
# San Luis                        Desoc         0.5
#                                 Inac
#                                 Menor de 14   4.0
#                                 Ocup          0.1
# Santa Cruz                      Desoc         0.8
#                                 Inac
#                                 Menor de 14   1.0
#                                 Ocup
# Santa Fe                        Desoc         6.5
#                                 Inac
#                                 Menor de 14  22.1
#                                 Ocup          0.9
# Santiago del Estero             Desoc         0.2
#                                 Inac
#                                 Menor de 14   2.7
#                                 Ocup          0.9
# Tierra del Fuego                Desoc         0.5
#                                 Inac
#                                 Menor de 14   0.6
#                                 Ocup
# Tucumán                         Desoc         1.0
#                                 Inac
#                                 Menor de 14   4.4
#                                 Ocup          0.2

# %% [markdown]
# ### Tabla: Poblacion en pobreza por aglomerado

# %%
# pd.read_csv('./../data/results/result_H_Q-AGLOMERADO.json')
base_str = 'P'; grouper = ['Q', 'AGLOMERADO']; frac = 0.01
info = pd.read_json('./../data/results/result_'+base_str+'_'+'-'.join(grouper)+'_'+str(frac)+'.json')
info['Q'] = pd.to_datetime(info['Q'])

## Chequea valores de distintos timestamps
# info.groupby(['observable', 'sintetico', 'base'] + grouper).nunique().value_counts()

## Pick latest timestamp for every value
info = info.sort_values('timestamp').groupby(['observable', 'sintetico', 'base'] + grouper).last().reset_index()
# info.timestamp.hist()

## Introducir nombres de aglomerados
nomaglos = pd.read_csv('./../data/info/aglo_labels.csv')[['AGLOMERADO', 'NOMAGLO']]
info['AGLOMERADO'] = info['AGLOMERADO'].map(dict(nomaglos.values))

## Variables disponibles
# info[['observable', 'sintetico', 'base']].drop_duplicates()

# %%
info.nunique()
# Out:
# observable       4
# sintetico        7
# base             1
# Q                8
# AGLOMERADO      33
# timestamp        8
# valor         1512
# frac             1
# dtype: int64

# %%
pobreza_sum = info.loc[(info.observable.isin(['Total', 'Pobreza'])) & (info.sintetico == 'sum')]

tabla_custom = pobreza_sum.set_index(grouper + ['observable'])['valor'].unstack([-2, -1]).T.sort_index()/1e3

tabla_custom.head(20)
# Out:
# Q                           2010-02-15  2010-05-15  2010-08-15  2010-11-15  \
# AGLOMERADO      observable
# Bahia Blanca    Pobreza           84.2        97.4        90.8        93.5
#                 Total            293.7       293.7       293.7       293.7
# CABA            Pobreza          450.7       494.1       437.0       457.2
#                 Total           2867.9      2867.9      2867.9      2867.9
# Catamarca       Pobreza           64.7        76.1        68.4        70.0
#                 Total            175.6       175.6       175.6       175.6
# Cdro Rivadavia  Pobreza           29.6        35.6        31.0        36.6
#                 Total            160.0       160.0       160.0       160.0
# Concordia       Pobreza           70.2        82.1        70.7        75.6
#                 Total            150.5       150.5       150.5       150.5
# Cordoba         Pobreza          470.5       525.2       480.5       489.3
#                 Total           1447.5      1447.5      1447.5      1447.5
# Corrientes      Pobreza          157.4       169.5       153.8       170.2
#                 Total            340.0       340.0       340.0       340.0
# Formosa         Pobreza          101.2       116.0       103.5       107.7
#                 Total            220.4       220.4       220.4       220.4
# Fuera de aglom. Pobreza         7165.4      7832.2      7209.6      7681.7
#                 Total          14760.6     14760.6     14760.6     14760.6
# GBA             Pobreza         4119.8      4425.5      3961.6      4285.6
#                 Total          10671.2     10671.2     10671.2     10671.2
#
# Q                           2011-02-15  2011-05-15  2011-08-15  2011-11-15
# AGLOMERADO      observable
# Bahia Blanca    Pobreza           77.3        89.3        86.9        83.9
#                 Total            288.0       288.0       288.0       288.0
# CABA            Pobreza          403.0       491.2       373.1       407.0
#                 Total           2928.9      2928.9      2928.9      2928.9
# Catamarca       Pobreza           60.2        77.5        65.7        75.9
#                 Total            180.5       180.5       180.5       180.5
# Cdro Rivadavia  Pobreza           35.8        45.9        35.5        41.9
#                 Total            162.4       162.4       162.4       162.4
# Concordia       Pobreza           64.9        79.9        71.6        78.7
#                 Total            149.2       149.2       149.2       149.2
# Cordoba         Pobreza          443.0       542.4       446.2       459.6
#                 Total           1466.2      1466.2      1466.2      1466.2
# Corrientes      Pobreza          161.2       162.8       160.4       160.8
#                 Total            344.3       344.3       344.3       344.3
# Formosa         Pobreza          111.4       120.5       115.1       113.8
#                 Total            229.4       229.4       229.4       229.4
# Fuera de aglom. Pobreza         6930.8      7730.5      7072.2      7326.0
#                 Total          15165.5     15165.5     15165.5     15165.5
# GBA             Pobreza         3911.2      4273.0      3836.6      3996.6
#                 Total          10738.8     10738.8     10738.8     10738.8

# %%
tabla_custom.to_excel('./personas_pob_total_AGLO.xlsx')

# %% [markdown]
# ### Grafico: Dist ingresos por AGLO

# %%
import numpy as np

# %%
# pd.read_csv('./../data/results/result_H_Q-AGLOMERADO.json')

base_str = 'M24'; grouper = ['Q', 'AGLOMERADO']
info = pd.read_json('./../data/results/result_'+base_str+'_'+'-'.join(grouper)+'_'+str(frac)+'.json')
info['Q'] = pd.to_datetime(info['Q'])

## Chequea valores de distintos timestamps
# info.groupby(['observable', 'sintetico', 'base'] + grouper).nunique().value_counts()

## Pick latest timestamp for every value
info = info.sort_values('timestamp').groupby(['observable', 'sintetico', 'base'] + grouper).last().reset_index()
# info.timestamp.hist()

## Introducir nombres de aglomerados
nomaglos = pd.read_csv('./../data/info/aglo_labels.csv')[['AGLOMERADO', 'NOMAGLO']]
info['AGLOMERADO'] = info['AGLOMERADO'].map(dict(nomaglos.values))

## Variables disponibles
# info[['observable', 'sintetico', 'base']].drop_duplicates()

# %%
ingresos = info.loc[info.observable.str.contains('P47T_')]
# info.observable.unique()
ingresos = ingresos[['sintetico', 'Q', 'AGLOMERADO', 'valor']]

# %%
ingresos_17 = ingresos.loc[ingresos['Q'].dt.year == 2010]

# %%
data = ingresos_17.groupby(['AGLOMERADO', 'sintetico'])['valor'].mean().unstack().sort_values('mean')

# %%
# _2017 = ['2017-02-15', '2017-05-15', '2017-08-15', '2017-11-15']

# tabla_custom[_2017]

import matplotlib.pyplot as plt
 
nAGLOS = ingresos['AGLOMERADO'].nunique()
x = range(nAGLOS)


y = data['median']

# creating error
y_errormin = data['median'] - data['q25']
y_errormax = data['q75'] - data['median']

x_error = 0
y_error =[y_errormin, y_errormax]
 
# plotting graph
# plt.plot(x, y)
fig, ax = plt.subplots(1, figsize = (10, 6))
plt.errorbar(x, y, capsize = 3,
             yerr = y_error,
             xerr = x_error,
             fmt ='o')

ax.set_yticks(np.arange(0, 3e4, 5e3)); 
ax.set_xticks(range(nAGLOS))
ax.set_xticklabels(data.index.values)

# plt.yscale('log'); plt.ylim(2e3, 5e4)

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(True, linestyle = '--')
plt.savefig('./example_fig.png')
plt.show()

# %% [markdown]
# ### Tabla: Poblacion en pobreza por provincia y Aglo si/no

# %%
# pd.read_csv('./../data/results/result_H_Q-AGLOMERADO.json')

base_str = 'P'; grouper = ['Q', 'PROV', 'AGLO_si']
info = pd.read_json('./../data/results/result_'+base_str+'_'+'-'.join(grouper)+'_'+str(frac)+'.json')
info['Q'] = pd.to_datetime(info['Q'])

## Pick latest timestamp for every value
info = info.sort_values('timestamp').groupby(['observable', 'sintetico', 'base'] + grouper).last().reset_index()

## Introducir nombres de provincia
nomprovs = pd.read_csv('./../data/info/prov_regs.csv')[['PROV', 'NOMPROV']]
info['PROV'] = info['PROV'].map(dict(nomprovs.values))

## Variables disponibles
# info[['observable', 'sintetico', 'base']].drop_duplicates()

# %%
pobreza_sum = info.loc[(info.observable.isin(['Total', 'Pobreza'])) & (info.sintetico == 'sum')]

tabla_custom = pobreza_sum.set_index(grouper + ['observable'])['valor'].unstack([-3, -2, -1]).T.sort_index()/1e3

tabla_custom.head()
# Out:
# Q                                2010-02-15  2010-05-15  2010-08-15  \
# PROV         AGLO_si observable
# Buenos Aires False   Pobreza         1156.7      1264.9      1125.6
#                      Total           3104.1      3104.1      3104.1
#              True    Pobreza         4689.0      5064.3      4535.7
#                      Total          12512.2     12512.2     12512.2
# Catamarca    False   Pobreza          118.4       123.2       115.9
#
# Q                                2010-11-15  2011-02-15  2011-05-15  \
# PROV         AGLO_si observable
# Buenos Aires False   Pobreza         1217.4      1101.1      1270.7
#                      Total           3104.1      3174.8      3174.8
#              True    Pobreza         4904.7      4398.3      4856.3
#                      Total          12512.2     12555.7     12555.7
# Catamarca    False   Pobreza          121.0       105.6       104.0
#
# Q                                2011-08-15  2011-11-15
# PROV         AGLO_si observable
# Buenos Aires False   Pobreza         1081.3      1173.2
#                      Total           3174.8      3174.8
#              True    Pobreza         4336.9      4529.5
#                      Total          12555.7     12555.7
# Catamarca    False   Pobreza          111.3       109.1

# %%
tabla_custom.to_excel('./personas_pob_total_PROV_AGLOsi.xlsx')

# %% [markdown]
# ## Graficos:
#
# ### Barras para cantidad de pobreza

# %%
tabla_custom.columns = pd.to_datetime(tabla_custom.columns)
# Out:
# Q                                                   2010-02-15  2010-05-15  \
# PROV                            AGLO_si observable
# Buenos Aires                    False   Pobreza         1156.7      1264.9
#                                         Total           3104.1      3104.1
#                                 True    Pobreza         4689.0      5064.3
#                                         Total          12512.2     12512.2
# Catamarca                       False   Pobreza          118.4       123.2
#                                         Total            197.3       197.3
#                                 True    Pobreza           64.7        76.1
#                                         Total            175.6       175.6
# Chaco                           False   Pobreza          446.9       481.1
#                                         Total            666.3       666.3
#                                 True    Pobreza          170.3       208.7
#                                         Total            382.6       382.6
# Chubut                          False   Pobreza           63.7        76.5
#                                         Total            227.0       227.0
#                                 True    Pobreza           59.9        73.9
#                                         Total            277.7       277.7
# Ciudad Autónoma de Buenos Aires False   Pobreza            0.4         0.0
#                                         Total              1.0         1.0
#                                 True    Pobreza          450.7       494.1
#                                         Total           2867.9      2867.9
# Corrientes                      False   Pobreza          390.9       418.5
#                                         Total            641.8       641.8
#                                 True    Pobreza          157.4       169.5
#                                         Total            340.0       340.0
# Córdoba                         False   Pobreza          683.7       753.9
#                                         Total           1688.1      1688.1
#                                 True    Pobreza          519.0       574.9
#                                         Total           1597.4      1597.4
# Entre Ríos                      False   Pobreza          386.0       418.3
#                                         Total            812.0       812.0
#                                 True    Pobreza          161.4       183.6
#                                         Total            423.7       423.7
# Formosa                         False   Pobreza          213.8       227.5
#                                         Total            314.5       314.5
#                                 True    Pobreza          101.2       116.0
#                                         Total            220.4       220.4
# Jujuy                           False   Pobreza          209.8       235.5
#                                         Total            358.9       358.9
#                                 True    Pobreza          124.3       147.6
#                                         Total            310.4       310.4
# La Pampa                        False   Pobreza           81.1        94.0
#                                         Total            206.1       206.1
#                                 True    Pobreza           35.5        41.5
#                                         Total            112.3       112.3
# La Rioja                        False   Pobreza           99.4       105.7
#                                         Total            163.1       163.1
#                                 True    Pobreza           83.1        88.8
#                                         Total            174.9       174.9
# Mendoza                         False   Pobreza          425.9       475.8
#                                         Total            814.8       814.8
#                                 True    Pobreza          341.6       388.0
#                                         Total            929.6       929.6
# Misiones                        False   Pobreza          509.6       566.5
#                                         Total            811.4       811.4
#                                 True    Pobreza          140.5       153.9
#                                         Total            295.0       295.0
# Neuquén                         False   Pobreza          107.0       114.3
#                                         Total            276.5       276.5
#                                 True    Pobreza           91.7        89.5
#                                         Total            272.9       272.9
# Río Negro                       False   Pobreza          167.5       178.4
#                                         Total            507.6       507.6
#                                 True    Pobreza           36.6        37.7
#                                         Total            123.0       123.0
# Salta                           False   Pobreza          424.7       461.2
#                                         Total            662.6       662.6
#                                 True    Pobreza          233.4       270.0
#                                         Total            553.0       553.0
# San Juan                        False   Pobreza          183.1       195.0
#                                         Total            278.2       278.2
#                                 True    Pobreza          184.7       202.9
#                                         Total            402.9       402.9
# San Luis                        False   Pobreza          102.5       127.6
#                                         Total            248.3       248.3
#                                 True    Pobreza           79.9        93.1
#                                         Total            183.9       183.9
# Santa Cruz                      False   Pobreza           50.6        53.8
#                                         Total            170.7       170.7
#                                 True    Pobreza           25.1        25.5
#                                         Total            106.9       106.9
# Santa Fe                        False   Pobreza          615.9       678.0
#                                         Total           1464.9      1464.9
#                                 True    Pobreza          599.6       669.5
#                                         Total           1708.3      1708.3
# Santiago del Estero             False   Pobreza          347.9       369.6
#                                         Total            501.6       501.6
#                                 True    Pobreza          157.5       191.0
#                                         Total            360.5       360.5
# Tierra del Fuego                False   Pobreza            7.3         6.2
#                                         Total             17.1        17.1
#                                 True    Pobreza           14.8        13.2
#                                         Total            102.4       102.4
# Tucumán                         False   Pobreza          372.6       406.7
#                                         Total            626.7       626.7
#                                 True    Pobreza          323.1       374.6
#                                         Total            811.3       811.3
#
# Q                                                   2010-08-15  2010-11-15
# PROV                            AGLO_si observable
# Buenos Aires                    False   Pobreza         1125.6      1217.4
#                                         Total           3104.1      3104.1
#                                 True    Pobreza         4535.7      4904.7
#                                         Total          12512.2     12512.2
# Catamarca                       False   Pobreza          115.9       121.0
#                                         Total            197.3       197.3
#                                 True    Pobreza           68.4        70.0
#                                         Total            175.6       175.6
# Chaco                           False   Pobreza          442.2       488.9
#                                         Total            666.3       666.3
#                                 True    Pobreza          187.4       199.2
#                                         Total            382.6       382.6
# Chubut                          False   Pobreza           70.2        71.5
#                                         Total            227.0       227.0
#                                 True    Pobreza           60.6        71.4
#                                         Total            277.7       277.7
# Ciudad Autónoma de Buenos Aires False   Pobreza            0.0         0.4
#                                         Total              1.0         1.0
#                                 True    Pobreza          437.0       457.2
#                                         Total           2867.9      2867.9
# Corrientes                      False   Pobreza          395.6       423.0
#                                         Total            641.8       641.8
#                                 True    Pobreza          153.8       170.2
#                                         Total            340.0       340.0
# Córdoba                         False   Pobreza          686.8       705.1
#                                         Total           1688.1      1688.1
#                                 True    Pobreza          530.3       539.4
#                                         Total           1597.4      1597.4
# Entre Ríos                      False   Pobreza          400.7       411.5
#                                         Total            812.0       812.0
#                                 True    Pobreza          168.1       184.3
#                                         Total            423.7       423.7
# Formosa                         False   Pobreza          216.3       240.1
#                                         Total            314.5       314.5
#                                 True    Pobreza          103.5       107.7
#                                         Total            220.4       220.4
# Jujuy                           False   Pobreza          204.8       230.0
#                                         Total            358.9       358.9
#                                 True    Pobreza          131.9       136.4
#                                         Total            310.4       310.4
# La Pampa                        False   Pobreza           72.8        83.3
#                                         Total            206.1       206.1
#                                 True    Pobreza           32.1        37.9
#                                         Total            112.3       112.3
# La Rioja                        False   Pobreza          104.0       105.2
#                                         Total            163.1       163.1
#                                 True    Pobreza           78.1        91.3
#                                         Total            174.9       174.9
# Mendoza                         False   Pobreza          445.3       491.7
#                                         Total            814.8       814.8
#                                 True    Pobreza          341.1       397.7
#                                         Total            929.6       929.6
# Misiones                        False   Pobreza          515.7       573.0
#                                         Total            811.4       811.4
#                                 True    Pobreza          129.5       144.5
#                                         Total            295.0       295.0
# Neuquén                         False   Pobreza          114.3       112.2
#                                         Total            276.5       276.5
#                                 True    Pobreza           88.9        93.5
#                                         Total            272.9       272.9
# Río Negro                       False   Pobreza          167.3       176.5
#                                         Total            507.6       507.6
#                                 True    Pobreza           33.2        42.3
#                                         Total            123.0       123.0
# Salta                           False   Pobreza          423.6       442.6
#                                         Total            662.6       662.6
#                                 True    Pobreza          239.0       236.5
#                                         Total            553.0       553.0
# San Juan                        False   Pobreza          188.3       199.8
#                                         Total            278.2       278.2
#                                 True    Pobreza          191.6       199.8
#                                         Total            402.9       402.9
# San Luis                        False   Pobreza          106.5       129.8
#                                         Total            248.3       248.3
#                                 True    Pobreza           80.3        97.7
#                                         Total            183.9       183.9
# Santa Cruz                      False   Pobreza           55.2        49.1
#                                         Total            170.7       170.7
#                                 True    Pobreza           23.3        28.9
#                                         Total            106.9       106.9
# Santa Fe                        False   Pobreza          621.4       643.7
#                                         Total           1464.9      1464.9
#                                 True    Pobreza          620.1       641.1
#                                         Total           1708.3      1708.3
# Santiago del Estero             False   Pobreza          353.5       354.4
#                                         Total            501.6       501.6
#                                 True    Pobreza          172.4       181.1
#                                         Total            360.5       360.5
# Tierra del Fuego                False   Pobreza            5.9         5.9
#                                         Total             17.1        17.1
#                                 True    Pobreza           13.4        11.8
#                                         Total            102.4       102.4
# Tucumán                         False   Pobreza          377.7       405.6
#                                         Total            626.7       626.7
#                                 True    Pobreza          355.5       366.6
#                                         Total            811.3       811.3

# %%
# _2017 = ['2017-02-15', '2017-05-15', '2017-08-15', '2017-11-15']

# tabla_custom_y = tabla_custom.T.loc['2010'].T
# data = tabla_custom_y.mean(1).unstack([-1, -2]).sort_index(axis = 1)

data = tabla_custom.mean(1).unstack([-1, -2]).sort_index(axis = 1)

print('Promedio de:', tabla_custom.columns)
data
# Out:
# Promedio de: DatetimeIndex(['2010-02-15', '2010-05-15', '2010-08-15', '2010-11-15',
#                '2011-02-15', '2011-05-15', '2011-08-15', '2011-11-15'],
#               dtype='datetime64[ns]', name='Q', freq=None)
# observable                         Pobreza               Total
# AGLO_si                              False       True    False      True
# PROV
# Buenos Aires                     1173.8625  4664.3375  3139.45  12533.95
# Catamarca                         113.5625    69.8125   196.30    178.05
# Chaco                             445.7250   193.3250   669.15    393.75
# Chubut                             80.1750    72.5000   232.95    280.90
# Ciudad Autónoma de Buenos Aires     0.1000   439.1625     1.05   2898.40
# Corrientes                        403.4250   162.0125   649.95    342.15
# Córdoba                           709.5250   533.1875  1711.15   1613.70
# Entre Ríos                        410.0875   174.0375   823.35    420.85
# Formosa                           216.7500   111.1500   316.10    224.90
# Jujuy                             222.6000   128.4625   368.20    311.10
# La Pampa                           80.5875    35.2625   208.55    112.75
# La Rioja                           97.4500    83.4000   162.10    174.60
# Mendoza                           451.4750   350.9375   825.35    929.80
# Misiones                          511.2375   134.3375   808.85    295.20
# Neuquén                           120.4750    89.3000   292.25    265.30
# Río Negro                         189.9000    35.9750   530.65    119.45
# Salta                             426.2625   241.6000   667.15    561.25
# San Juan                          174.5500   192.2625   268.15    407.75
# San Luis                          121.9500    85.2750   252.60    187.15
# Santa Cruz                         52.0625    23.0875   203.70     99.65
# Santa Fe                          616.8125   624.1375  1470.85   1722.90
# Santiago del Estero               361.9250   167.9000   511.50    364.35
# Tierra del Fuego                    5.6875    15.4750    15.85    109.95
# Tucumán                           382.3625   354.8500   637.85    812.75

# %%
# import matplotlib.pyplot as plt
# colors = plt.cm.Paired.colors

# fig, ax = plt.subplots(1, figsize = (15, 10))
# # (data['Pobreza']+data['Total']).plot(kind='bar', color=[colors[1], colors[0]], rot=0, ax=ax) # stacked
# data['Total'].plot(kind='bar', color=['.5', '.5'], rot=0, ax=ax, alpha = .5)
# data['Pobreza'].plot(kind='bar', color=[colors[3], colors[2]], rot=0, ax=ax, alpha = 1)

# # legend_labels = [f'{val} ({context})' for val, context in data.columns]
# # ax.legend(legend_labels)

# plt.xticks(rotation=45, ha='right')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### Ingreso por provincia
